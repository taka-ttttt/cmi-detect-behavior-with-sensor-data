# %% [markdown]
# # Imports and configs

# %%
# Core libraries
import os
import json
import joblib
import random
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import polars as pl

# Suppress warnings
warnings.filterwarnings("ignore")
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Scikit-learn
from sklearn.model_selection import (
    train_test_split, StratifiedGroupKFold, GroupKFold
)
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    f1_score, classification_report, confusion_matrix, 
    accuracy_score, precision_recall_fscore_support,
    recall_score, precision_score
)

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.utils import Sequence, to_categorical, pad_sequences
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, Activation, add, MaxPooling1D, 
    Dropout, Bidirectional, LSTM, GRU, GlobalAveragePooling1D, 
    GlobalMaxPooling1D, Dense, Multiply, Reshape, Lambda, 
    Concatenate, GaussianNoise, SeparableConv1D, DepthwiseConv1D,
    LayerNormalization, MultiHeadAttention, Embedding
)
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, 
    LearningRateScheduler, CSVLogger
)
from tensorflow.keras.losses import (
    CategoricalCrossentropy, SparseCategoricalCrossentropy
)
from tensorflow.keras import backend as K

# Scientific computing
from scipy.spatial.transform import Rotation as R
from scipy import stats
from scipy.signal import find_peaks, periodogram
from scipy.fft import fft, fftfreq

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Progress bar
from tqdm import tqdm

# %%
import random
def seed_everything(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.experimental.numpy.random.seed(seed)
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
seed_everything(seed=42)

# %%
class DLConfig:
    seed = 42
    n_folds = 5
    
    # Model parameters
    batch_size = 64
    epochs = 160
    patience = 40
    lr_init = 5e-4
    weight_decay = 3e-3
    mixup_alpha = 0.4
    
    # Data parameters
    pad_percentile = 95
    
    # BFRB gesture mapping
    bfrb_gestures = [
        'Above ear - pull hair',
        'Cheek - pinch skin', 
        'Eyebrow - pull hair',
        'Eyelash - pull hair',
        'Forehead - pull hairline',
        'Forehead - scratch',
        'Neck - pinch skin',
        'Neck - scratch'
    ]

np.random.seed(DLConfig.seed)
tf.random.set_seed(DLConfig.seed)

print("▶ imports ready · tensorflow", tf.__version__)
# Out:
# ▶ imports ready · tensorflow 2.19.0

# %%
class Config:
    train_path = "input/train.csv"
    train_demographic_path = "input/train_demographics.csv"
    test_path = "input/test.csv"
    test_demographic_path = "input/test_demographics.csv"

    target = "gesture"
    
    n_folds = 5
    seed = 42

    run_optuna = True
    n_optuna_trials = 100

# %% [markdown]
# # Utility Functions

# %%
#Tensor Manipulations
def time_sum(x):
    return K.sum(x, axis=1)

def squeeze_last_axis(x):
    return tf.squeeze(x, axis=-1)

def expand_last_axis(x):
    return tf.expand_dims(x, axis=-1)

def se_block(x, reduction=8):
    ch = x.shape[-1]
    se = GlobalAveragePooling1D()(x)
    se = Dense(ch // reduction, activation='relu')(se)
    se = Dense(ch, activation='sigmoid')(se)
    se = Reshape((1, ch))(se)
    return Multiply()([x, se])

# Residual CNN Block with SE
def residual_se_cnn_block(x, filters, kernel_size, pool_size=2, drop=0.3, wd=1e-4):
    shortcut = x
    for _ in range(2):
        x = Conv1D(filters, kernel_size, padding='same', use_bias=False,
                   kernel_regularizer=l2(wd))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
    x = se_block(x)
    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding='same', use_bias=False,
                          kernel_regularizer=l2(wd))(shortcut)
        shortcut = BatchNormalization()(shortcut)
    x = add([x, shortcut])
    x = Activation('relu')(x)
    x = MaxPooling1D(pool_size)(x)
    x = Dropout(drop)(x)
    return x

def attention_layer(inputs):
    score = Dense(1, activation='tanh')(inputs)
    score = Lambda(squeeze_last_axis)(score)
    weights = Activation('softmax')(score)
    weights = Lambda(expand_last_axis)(weights)
    context = Multiply()([inputs, weights])
    context = Lambda(time_sum)(context)
    return context

# %% [markdown]
# # Feature engineering

# %%
class MixupGenerator(Sequence):
    def __init__(self, X, y, batch_size, alpha=0.2):
        self.X, self.y = X, y
        self.batch = batch_size
        self.alpha = alpha
        self.indices = np.arange(len(X))
    
    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch))
    
    def __getitem__(self, i):
        idx = self.indices[i*self.batch:(i+1)*self.batch]
        Xb, yb = self.X[idx], self.y[idx]
        lam = np.random.beta(self.alpha, self.alpha)
        perm = np.random.permutation(len(Xb))
        X_mix = lam * Xb + (1-lam) * Xb[perm]
        y_mix = lam * yb + (1-lam) * yb[perm]
        return X_mix, y_mix
    
    def on_epoch_end(self):
        np.random.shuffle(self.indices)

# %%
def remove_gravity_from_acc(acc_data, rot_data) -> np.ndarray:

    if isinstance(acc_data, pd.DataFrame):
        acc_values = acc_data[['acc_x', 'acc_y', 'acc_z']].values
    else:
        acc_values = acc_data

    if isinstance(rot_data, pd.DataFrame):
        quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    else:
        quat_values = rot_data

    num_samples = acc_values.shape[0]
    linear_accel = np.zeros_like(acc_values)
    
    gravity_world = np.array([0, 0, 9.81])

    for i in range(num_samples):
        if np.all(np.isnan(quat_values[i])) or np.all(np.isclose(quat_values[i], 0)):
            linear_accel[i, :] = acc_values[i, :] 
            continue

        try:
            rotation = R.from_quat(quat_values[i])
            gravity_sensor_frame = rotation.apply(gravity_world, inverse=True)
            linear_accel[i, :] = acc_values[i, :] - gravity_sensor_frame
        except ValueError:
             linear_accel[i, :] = acc_values[i, :]
             
    return linear_accel


def calculate_angular_velocity_from_quat(rot_data, time_delta=1/10) -> np.ndarray: # Assuming 10Hz sampling rate
    if isinstance(rot_data, pd.DataFrame):
        quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    else:
        quat_values = rot_data

    num_samples = quat_values.shape[0]
    angular_vel = np.zeros((num_samples, 3))

    for i in range(num_samples - 1):
        q_t = quat_values[i]
        q_t_plus_dt = quat_values[i+1]

        if np.all(np.isnan(q_t)) or np.all(np.isclose(q_t, 0)) or \
           np.all(np.isnan(q_t_plus_dt)) or np.all(np.isclose(q_t_plus_dt, 0)):
            continue

        try:
            rot_t = R.from_quat(q_t)
            rot_t_plus_dt = R.from_quat(q_t_plus_dt)

            # Calculate the relative rotation
            delta_rot = rot_t.inv() * rot_t_plus_dt
            
            # Convert delta rotation to angular velocity vector
            # The rotation vector (Euler axis * angle) scaled by 1/dt
            # is a good approximation for small delta_rot
            angular_vel[i, :] = delta_rot.as_rotvec() / time_delta
        except ValueError:
            # If quaternion is invalid, angular velocity remains zero
            pass
            
    return angular_vel


def calculate_angular_distance(rot_data) -> np.ndarray:
    if isinstance(rot_data, pd.DataFrame):
        quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    else:
        quat_values = rot_data

    num_samples = quat_values.shape[0]
    angular_dist = np.zeros(num_samples)

    for i in range(num_samples - 1):
        q1 = quat_values[i]
        q2 = quat_values[i+1]

        if np.all(np.isnan(q1)) or np.all(np.isclose(q1, 0)) or \
           np.all(np.isnan(q2)) or np.all(np.isclose(q2, 0)):
            angular_dist[i] = 0 # Или np.nan, в зависимости от желаемого поведения
            continue
        try:
            # Преобразование кватернионов в объекты Rotation
            r1 = R.from_quat(q1)
            r2 = R.from_quat(q2)

            # Вычисление углового расстояния: 2 * arccos(|real(p * q*)|)
            # где p* - сопряженный кватернион q
            # В scipy.spatial.transform.Rotation, r1.inv() * r2 дает относительное вращение.
            # Угол этого относительного вращения - это и есть угловое расстояние.
            relative_rotation = r1.inv() * r2
            
            # Угол rotation vector соответствует угловому расстоянию
            # Норма rotation vector - это угол в радианах
            angle = np.linalg.norm(relative_rotation.as_rotvec())
            angular_dist[i] = angle
        except ValueError:
            angular_dist[i] = 0 # В случае недействительных кватернионов
            pass
            
    return angular_dist

# %%
def build_gesture_model(pad_len, imu_dim, extra_dim, n_classes, wd=1e-4):
    """
    Two-branch architecture similar to URL Notebook
    """
    inp = Input(shape=(pad_len, imu_dim + extra_dim))
    
    # Split into IMU and extra sensor branches
    imu = Lambda(lambda t: t[:, :, :imu_dim])(inp)
    extra = Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # IMU deep branch (for precise temporal patterns)
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.1, wd=wd)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.1, wd=wd)

    # Extra sensor lighter branch (for thermal/ToF)
    x2 = Conv1D(64, 3, padding='same', use_bias=False, kernel_regularizer=l2(wd))(extra)
    x2 = BatchNormalization()(x2)
    x2 = Activation('relu')(x2)
    x2 = MaxPooling1D(2)(x2)
    x2 = Dropout(0.2)(x2)
    
    x2 = Conv1D(128, 3, padding='same', use_bias=False, kernel_regularizer=l2(wd))(x2)
    x2 = BatchNormalization()(x2)
    x2 = Activation('relu')(x2)
    x2 = MaxPooling1D(2)(x2)
    x2 = Dropout(0.2)(x2)

    # Merge branches
    merged = Concatenate()([x1, x2])

    # RNN layers
    xa = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(wd)))(merged)
    xb = Bidirectional(GRU(128, return_sequences=True, kernel_regularizer=l2(wd)))(merged)
    xc = GaussianNoise(0.09)(merged)
    xc = Dense(16, activation='elu')(xc)
    
    # Concatenate and apply attention
    x = Concatenate()([xa, xb, xc])
    x = Dropout(0.4)(x)
    x = attention_layer(x)

    # Classification head
    for units, drop in [(256, 0.5), (128, 0.3)]:
        x = Dense(units, use_bias=False, kernel_regularizer=l2(wd))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Dropout(drop)(x)

    output = Dense(n_classes, activation='softmax', kernel_regularizer=l2(wd))(x)
    
    model = Model(inp, output)
    return model

# %%
def create_imu_features(df):
    """
    Create imu features
    """
    features_df = df.copy()
    
    # Basic engineered features
    features_df['acc_mag'] = np.sqrt(df['acc_x']**2 + df['acc_y']**2 + df['acc_z']**2)
    features_df['rot_angle'] = 2 * np.arccos(df['rot_w'].clip(-1, 1))
    
    # Derivatives
    features_df['acc_mag_jerk'] = features_df.groupby('sequence_id')['acc_mag'].diff().fillna(0)
    features_df['rot_angle_vel'] = features_df.groupby('sequence_id')['rot_angle'].diff().fillna(0)
    
    # Linear acceleration (gravity removal)
    linear_accel_list = []
    for seq_id, group in features_df.groupby('sequence_id'):
        acc_data = group[['acc_x', 'acc_y', 'acc_z']]
        rot_data = group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]
        linear_accel = remove_gravity_from_acc(acc_data, rot_data)  # Use existing function
        linear_accel_df = pd.DataFrame(
            linear_accel, 
            columns=['linear_acc_x', 'linear_acc_y', 'linear_acc_z'], 
            index=group.index
        )
        linear_accel_list.append(linear_accel_df)
    
    linear_accel_combined = pd.concat(linear_accel_list)
    features_df = pd.concat([features_df, linear_accel_combined], axis=1)
    
    # Linear acceleration magnitude and derivatives
    features_df['linear_acc_mag'] = np.sqrt(
        features_df['linear_acc_x']**2 + 
        features_df['linear_acc_y']**2 + 
        features_df['linear_acc_z']**2
    )
    features_df['linear_acc_mag_jerk'] = features_df.groupby('sequence_id')['linear_acc_mag'].diff().fillna(0)
    
    # Angular velocity from quaternions
    angular_vel_list = []
    for seq_id, group in features_df.groupby('sequence_id'):
        rot_data = group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]
        angular_vel = calculate_angular_velocity_from_quat(rot_data, time_delta=1/10)  # Use existing function
        angular_vel_df = pd.DataFrame(
            angular_vel,
            columns=['angular_vel_x', 'angular_vel_y', 'angular_vel_z'],
            index=group.index
        )
        angular_vel_list.append(angular_vel_df)
    
    angular_vel_combined = pd.concat(angular_vel_list)
    features_df = pd.concat([features_df, angular_vel_combined], axis=1)
    
    # Angular distance
    angular_dist_list = []
    for seq_id, group in features_df.groupby('sequence_id'):
        rot_data = group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]
        angular_dist = calculate_angular_distance(rot_data)  # Use existing function
        angular_dist_df = pd.DataFrame(
            angular_dist,
            columns=['angular_distance'],
            index=group.index
        )
        angular_dist_list.append(angular_dist_df)
    
    angular_dist_combined = pd.concat(angular_dist_list)
    features_df = pd.concat([features_df, angular_dist_combined], axis=1)
    
    return features_df

def prepare_sequences_for_dl(df, config, label_column='e_gesture'):
    """
    Prepare sequences for deep learning training
    """
    print("Creating features...")
    df_features = create_imu_features(df)
    
    # Define feature columns (similar to URL Notebook)
    imu_base_cols = ['linear_acc_x', 'linear_acc_y', 'linear_acc_z', 
                     'rot_x', 'rot_y', 'rot_z', 'rot_w']
    
    imu_engineered_cols = [
        'acc_mag', 'rot_angle', 'acc_mag_jerk', 'rot_angle_vel',
        'linear_acc_mag', 'linear_acc_mag_jerk',
        'angular_vel_x', 'angular_vel_y', 'angular_vel_z',
        'angular_distance'
    ]
    
    imu_cols = imu_base_cols + imu_engineered_cols
    
    # Thermal columns
    thm_cols = [f'thm_{i}' for i in range(1, 6)]
    
    # ToF aggregated features
    tof_agg_cols = []
    for i in range(1, 6):
        tof_agg_cols.extend([f'tof_{i}_mean', f'tof_{i}_std', f'tof_{i}_min', f'tof_{i}_max'])
    
    # Build sequences
    X_list, y_list, seq_ids = [], [], []
    
    print("Building sequences...")
    for seq_id, seq_df in tqdm(df_features.groupby('sequence_id'), desc="Processing sequences"):
        # Create ToF aggregated features
        for i in range(1, 6):
            pixel_cols = [f"tof_{i}_v{p}" for p in range(64)]
            if all(col in seq_df.columns for col in pixel_cols):
                tof_data = seq_df[pixel_cols].replace(-1, np.nan)
                seq_df[f'tof_{i}_mean'] = tof_data.mean(axis=1)
                seq_df[f'tof_{i}_std'] = tof_data.std(axis=1)
                seq_df[f'tof_{i}_min'] = tof_data.min(axis=1)
                seq_df[f'tof_{i}_max'] = tof_data.max(axis=1)
            else:
                seq_df[f'tof_{i}_mean'] = 0
                seq_df[f'tof_{i}_std'] = 0
                seq_df[f'tof_{i}_min'] = 0
                seq_df[f'tof_{i}_max'] = 0
        
        # Combine all features
        all_feature_cols = imu_cols + thm_cols + tof_agg_cols
        feature_matrix = seq_df[all_feature_cols].fillna(0).values.astype('float32')
        
        X_list.append(feature_matrix)
        y_list.append(seq_df[label_column].iloc[0])  # Gesture label
        seq_ids.append(seq_id)
    
    return X_list, np.array(y_list), np.array(seq_ids), len(imu_cols), len(thm_cols + tof_agg_cols)

# %% [markdown]
# # Training & Validation

# %%
def train_deep_learning_cv(X_list, y, seq_ids, subjects, gesture_classes, 
                          imu_dim, extra_dim, config, model_name="Model"):
    """
    Train deep learning model with proper cross-validation
    """
    print(f"\n=== {model_name} Deep Learning CV ===")
    print(f"Total sequences: {len(X_list)}")
    print(f"Classes: {len(gesture_classes)}")
    print(f"IMU features: {imu_dim}, Extra features: {extra_dim}")
    
    # Prepare data
    lens = [len(x) for x in X_list]
    pad_len = int(np.percentile(lens, config.pad_percentile))
    print(f"Padding length: {pad_len}")
    
    # Pad sequences
    X_padded = pad_sequences(X_list, maxlen=pad_len, padding='post', 
                           truncating='post', dtype='float32')
    y_categorical = to_categorical(y, num_classes=len(gesture_classes))
    
    # Scale data
    scaler = StandardScaler()
    X_scaled_list = []
    for i in range(len(X_padded)):
        X_scaled = scaler.fit_transform(X_padded[i])
        X_scaled_list.append(X_scaled)
    X_scaled = np.array(X_scaled_list)
    
    # Cross-validation setup
    sgkf = StratifiedGroupKFold(n_splits=config.n_folds, shuffle=True, random_state=config.seed)
    
    fold_results = []
    all_predictions = []
    all_true_labels = []
    
    for fold, (train_idx, val_idx) in enumerate(sgkf.split(X_scaled, y, groups=subjects)):
        print(f"\nFold {fold + 1}/{config.n_folds}")
        
        # Split data
        X_train, X_val = X_scaled[train_idx], X_scaled[val_idx]
        y_train, y_val = y_categorical[train_idx], y_categorical[val_idx]
        
        print(f"Train: {len(X_train)}, Val: {len(X_val)}")
        
        # Class weights
        y_train_int = y[train_idx]
        class_weights = compute_class_weight('balanced', 
                                           classes=np.arange(len(gesture_classes)), 
                                           y=y_train_int)
        class_weight_dict = dict(enumerate(class_weights))
        
        # Build model
        model = build_gesture_model(pad_len, imu_dim, extra_dim, 
                                  len(gesture_classes), wd=config.weight_decay)
        
        # Compile model
        model.compile(
            optimizer=Adam(learning_rate=config.lr_init),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        # Callbacks
        callbacks = [
            EarlyStopping(patience=config.patience, restore_best_weights=True, 
                         monitor='val_accuracy', mode='max', verbose=1),
            ReduceLROnPlateau(factor=0.5, patience=config.patience//2, 
                            monitor='val_accuracy', mode='max', verbose=1)
        ]
        
        # Training generator
        train_gen = MixupGenerator(X_train, y_train, 
                                 batch_size=config.batch_size, 
                                 alpha=config.mixup_alpha)
        
        # Train model
        history = model.fit(
            train_gen,
            epochs=config.epochs,
            validation_data=(X_val, y_val),
            class_weight=class_weight_dict,
            callbacks=callbacks,
            verbose=1
        )
        
        # Validation predictions
        val_pred_proba = model.predict(X_val)
        val_pred = np.argmax(val_pred_proba, axis=1)
        val_true = np.argmax(y_val, axis=1)
        
        # Calculate metrics
        fold_accuracy = np.mean(val_pred == val_true)
        fold_f1_macro = f1_score(val_true, val_pred, average='macro')
        
        fold_results.append({
            'fold': fold + 1,
            'accuracy': fold_accuracy,
            'f1_macro': fold_f1_macro,
            'best_epoch': len(history.history['loss'])
        })
        
        all_predictions.extend(val_pred)
        all_true_labels.extend(val_true)
        
        print(f"Fold {fold + 1} - Accuracy: {fold_accuracy:.4f}, F1-macro: {fold_f1_macro:.4f}")
        
        # Clear memory
        del model
        K.clear_session()
    
    # Overall results
    overall_accuracy = np.mean([r['accuracy'] for r in fold_results])
    overall_f1_macro = np.mean([r['f1_macro'] for r in fold_results])
    
    print(f"\n=== {model_name} CV Results ===")
    print(f"CV Accuracy: {overall_accuracy:.4f} ± {np.std([r['accuracy'] for r in fold_results]):.4f}")
    print(f"CV F1-macro: {overall_f1_macro:.4f} ± {np.std([r['f1_macro'] for r in fold_results]):.4f}")
    
    # Detailed classification report
    print(f"\n=== {model_name} Classification Report ===")
    print(classification_report(all_true_labels, all_predictions, 
                              target_names=gesture_classes, digits=4))
    
    return {
        'fold_results': fold_results,
        'overall_accuracy': overall_accuracy,
        'overall_f1_macro': overall_f1_macro,
        'predictions': all_predictions,
        'true_labels': all_true_labels
    }

# %%
config = DLConfig()

# Load and prepare data
print("Loading data...")
train = pd.read_csv(Config.train_path)
train_d = pd.read_csv(Config.train_demographic_path)

# Add subject information
train = train.merge(train_d[['subject']], on='subject', how='left')

# Label encoding
le_all = LabelEncoder()
train["e_gesture"] = le_all.fit_transform(train["gesture"])
all_gesture_classes = le_all.classes_

# Get subjects for grouping
subject_mapping = train.groupby('sequence_id')['subject'].first()

print(f"Total gestures: {len(all_gesture_classes)}")
print(f"BFRB gestures: {len(config.bfrb_gestures)}")
# Out:
# Loading data...
# Total gestures: 18
# BFRB gestures: 8

# %%
print("\n" + "="*60)
print("All 18 Gestures Classification")
print("="*60)

# Prepare sequences for all gestures
X_all, y_all, seq_ids_all, imu_dim, extra_dim = prepare_sequences_for_dl(train, config)
subjects_all = np.array([subject_mapping[seq_id] for seq_id in seq_ids_all])

# Train all gestures model
results_all = train_deep_learning_cv(
    X_all, y_all, seq_ids_all, subjects_all, all_gesture_classes,
    imu_dim, extra_dim, config, "All 18 Gestures"
)
# Out:
# ============================================================
# All 18 Gestures Classification
# ============================================================
# Creating features...
# Building sequences...
# Processing sequences: 100%|██████████| 8151/8151 [01:10<00:00, 116.19it/s]
# === All 18 Gestures Deep Learning CV ===
# Total sequences: 8151
# Classes: 18
# IMU features: 17, Extra features: 25
# Padding length: 127
#
# Fold 1/5
# Train: 6623, Val: 1528
# WARNING:tensorflow:From c:\Users\takah\Documents\02_study\kaggle\cmi-detect-behavior-with-sensor-data\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.0972 - loss: 9.8467 - val_accuracy: 0.1819 - val_loss: 8.3431 - learning_rate: 5.0000e-04
# Epoch 2/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.2085 - loss: 7.9625 - val_accuracy: 0.3809 - val_loss: 6.7205 - learning_rate: 5.0000e-04
# Epoch 3/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.2752 - loss: 6.7351 - val_accuracy: 0.4287 - val_loss: 5.5995 - learning_rate: 5.0000e-04
# Epoch 4/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.3335 - loss: 5.7859 - val_accuracy: 0.4614 - val_loss: 4.7692 - learning_rate: 5.0000e-04
# Epoch 5/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.3820 - loss: 5.0873 - val_accuracy: 0.4045 - val_loss: 4.5582 - learning_rate: 5.0000e-04
# Epoch 6/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.4174 - loss: 4.5713 - val_accuracy: 0.5236 - val_loss: 3.7907 - learning_rate: 5.0000e-04
# Epoch 7/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.4435 - loss: 4.2115 - val_accuracy: 0.4921 - val_loss: 3.5376 - learning_rate: 5.0000e-04
# Epoch 8/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.4470 - loss: 3.8853 - val_accuracy: 0.5079 - val_loss: 3.3489 - learning_rate: 5.0000e-04
# Epoch 9/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.4534 - loss: 3.5815 - val_accuracy: 0.5170 - val_loss: 2.9938 - learning_rate: 5.0000e-04
# Epoch 10/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.4828 - loss: 3.2703 - val_accuracy: 0.4784 - val_loss: 2.9756 - learning_rate: 5.0000e-04
# Epoch 11/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.5116 - loss: 3.0679 - val_accuracy: 0.4974 - val_loss: 2.7699 - learning_rate: 5.0000e-04
# Epoch 12/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.5497 - loss: 2.8669 - val_accuracy: 0.6001 - val_loss: 2.4115 - learning_rate: 5.0000e-04
# Epoch 13/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.5496 - loss: 2.7292 - val_accuracy: 0.5687 - val_loss: 2.3565 - learning_rate: 5.0000e-04
# Epoch 14/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.5543 - loss: 2.6110 - val_accuracy: 0.5864 - val_loss: 2.1808 - learning_rate: 5.0000e-04
# Epoch 15/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.5686 - loss: 2.4529 - val_accuracy: 0.5478 - val_loss: 2.1674 - learning_rate: 5.0000e-04
# Epoch 16/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.5791 - loss: 2.3052 - val_accuracy: 0.5812 - val_loss: 2.0239 - learning_rate: 5.0000e-04
# Epoch 17/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.5903 - loss: 2.2128 - val_accuracy: 0.5766 - val_loss: 2.0489 - learning_rate: 5.0000e-04
# Epoch 18/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.5685 - loss: 2.3068 - val_accuracy: 0.5301 - val_loss: 2.1256 - learning_rate: 5.0000e-04
# Epoch 19/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.5994 - loss: 2.0880 - val_accuracy: 0.6060 - val_loss: 1.8169 - learning_rate: 5.0000e-04
# Epoch 20/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.5845 - loss: 2.1624 - val_accuracy: 0.5864 - val_loss: 1.8139 - learning_rate: 5.0000e-04
# Epoch 21/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6131 - loss: 2.0436 - val_accuracy: 0.6243 - val_loss: 1.7668 - learning_rate: 5.0000e-04
# Epoch 22/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.5903 - loss: 2.0322 - val_accuracy: 0.6531 - val_loss: 1.6275 - learning_rate: 5.0000e-04
# Epoch 23/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.6192 - loss: 2.0170 - val_accuracy: 0.5792 - val_loss: 1.7693 - learning_rate: 5.0000e-04
# Epoch 24/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.5984 - loss: 2.0114 - val_accuracy: 0.5825 - val_loss: 1.7031 - learning_rate: 5.0000e-04
# Epoch 25/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6378 - loss: 1.8192 - val_accuracy: 0.6473 - val_loss: 1.6136 - learning_rate: 5.0000e-04
# Epoch 26/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6372 - loss: 1.8111 - val_accuracy: 0.5497 - val_loss: 1.7877 - learning_rate: 5.0000e-04
# Epoch 27/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6320 - loss: 1.8626 - val_accuracy: 0.6145 - val_loss: 1.6344 - learning_rate: 5.0000e-04
# Epoch 28/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.6429 - loss: 1.8265 - val_accuracy: 0.4228 - val_loss: 2.3048 - learning_rate: 5.0000e-04
# Epoch 29/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.6553 - loss: 1.7068 - val_accuracy: 0.6054 - val_loss: 1.6358 - learning_rate: 5.0000e-04
# Epoch 30/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6540 - loss: 1.7342 - val_accuracy: 0.5988 - val_loss: 1.6626 - learning_rate: 5.0000e-04
# Epoch 31/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6513 - loss: 1.7511 - val_accuracy: 0.5648 - val_loss: 1.7349 - learning_rate: 5.0000e-04
# Epoch 32/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6465 - loss: 1.7151 - val_accuracy: 0.5982 - val_loss: 1.5754 - learning_rate: 5.0000e-04
# Epoch 33/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6952 - loss: 1.5563 - val_accuracy: 0.6139 - val_loss: 1.5870 - learning_rate: 5.0000e-04
# Epoch 34/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6319 - loss: 1.7838 - val_accuracy: 0.6630 - val_loss: 1.4175 - learning_rate: 5.0000e-04
# Epoch 35/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6692 - loss: 1.5930 - val_accuracy: 0.6099 - val_loss: 1.5411 - learning_rate: 5.0000e-04
# Epoch 36/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6661 - loss: 1.6400 - val_accuracy: 0.6695 - val_loss: 1.3921 - learning_rate: 5.0000e-04
# Epoch 37/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6482 - loss: 1.8483 - val_accuracy: 0.5949 - val_loss: 1.5331 - learning_rate: 5.0000e-04
# Epoch 38/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6883 - loss: 1.6011 - val_accuracy: 0.6754 - val_loss: 1.4595 - learning_rate: 5.0000e-04
# Epoch 39/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7152 - loss: 1.4398 - val_accuracy: 0.5982 - val_loss: 1.5263 - learning_rate: 5.0000e-04
# Epoch 40/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.6617 - loss: 1.7308 - val_accuracy: 0.6486 - val_loss: 1.4865 - learning_rate: 5.0000e-04
# Epoch 41/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7153 - loss: 1.5111 - val_accuracy: 0.6662 - val_loss: 1.3591 - learning_rate: 5.0000e-04
# Epoch 42/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6508 - loss: 1.7410 - val_accuracy: 0.6355 - val_loss: 1.4622 - learning_rate: 5.0000e-04
# Epoch 43/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7358 - loss: 1.4227 - val_accuracy: 0.5759 - val_loss: 1.6365 - learning_rate: 5.0000e-04
# Epoch 44/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6781 - loss: 1.5933 - val_accuracy: 0.5452 - val_loss: 1.7497 - learning_rate: 5.0000e-04
# Epoch 45/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7163 - loss: 1.4315 - val_accuracy: 0.6296 - val_loss: 1.4864 - learning_rate: 5.0000e-04
# Epoch 46/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.7094 - loss: 1.5647 - val_accuracy: 0.6250 - val_loss: 1.4955 - learning_rate: 5.0000e-04
# Epoch 47/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6887 - loss: 1.6191 - val_accuracy: 0.5805 - val_loss: 1.5896 - learning_rate: 5.0000e-04
# Epoch 48/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7035 - loss: 1.5870 - val_accuracy: 0.6355 - val_loss: 1.4607 - learning_rate: 5.0000e-04
# Epoch 49/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.7246 - loss: 1.5183 - val_accuracy: 0.6774 - val_loss: 1.3316 - learning_rate: 5.0000e-04
# Epoch 50/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6932 - loss: 1.5821 - val_accuracy: 0.6158 - val_loss: 1.5284 - learning_rate: 5.0000e-04
# Epoch 51/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.7673 - loss: 1.3452 - val_accuracy: 0.5445 - val_loss: 1.7490 - learning_rate: 5.0000e-04
# Epoch 52/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.7303 - loss: 1.5120 - val_accuracy: 0.6898 - val_loss: 1.2755 - learning_rate: 5.0000e-04
# Epoch 53/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7429 - loss: 1.4874 - val_accuracy: 0.6433 - val_loss: 1.3967 - learning_rate: 5.0000e-04
# Epoch 54/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7405 - loss: 1.4297 - val_accuracy: 0.6387 - val_loss: 1.4468 - learning_rate: 5.0000e-04
# Epoch 55/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7208 - loss: 1.5914 - val_accuracy: 0.6237 - val_loss: 1.4913 - learning_rate: 5.0000e-04
# Epoch 56/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7271 - loss: 1.4773 - val_accuracy: 0.6656 - val_loss: 1.4040 - learning_rate: 5.0000e-04
# Epoch 57/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6995 - loss: 1.6252 - val_accuracy: 0.6348 - val_loss: 1.4702 - learning_rate: 5.0000e-04
# Epoch 58/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7275 - loss: 1.4948 - val_accuracy: 0.5877 - val_loss: 1.6626 - learning_rate: 5.0000e-04
# Epoch 59/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7421 - loss: 1.5308 - val_accuracy: 0.5923 - val_loss: 1.6168 - learning_rate: 5.0000e-04
# Epoch 60/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7278 - loss: 1.5963 - val_accuracy: 0.6211 - val_loss: 1.5594 - learning_rate: 5.0000e-04
# Epoch 61/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7607 - loss: 1.3847 - val_accuracy: 0.5923 - val_loss: 1.5346 - learning_rate: 5.0000e-04
# Epoch 62/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7515 - loss: 1.4273 - val_accuracy: 0.6381 - val_loss: 1.4263 - learning_rate: 5.0000e-04
# Epoch 63/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7337 - loss: 1.4543 - val_accuracy: 0.6590 - val_loss: 1.4008 - learning_rate: 5.0000e-04
# Epoch 64/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7470 - loss: 1.4794 - val_accuracy: 0.6401 - val_loss: 1.4302 - learning_rate: 5.0000e-04
# Epoch 65/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7725 - loss: 1.3142 - val_accuracy: 0.6276 - val_loss: 1.4864 - learning_rate: 5.0000e-04
# Epoch 66/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7570 - loss: 1.3884 - val_accuracy: 0.6545 - val_loss: 1.3786 - learning_rate: 5.0000e-04
# Epoch 67/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7217 - loss: 1.6091 - val_accuracy: 0.6669 - val_loss: 1.3845 - learning_rate: 5.0000e-04
# Epoch 68/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7694 - loss: 1.4605 - val_accuracy: 0.5615 - val_loss: 1.7823 - learning_rate: 5.0000e-04
# Epoch 69/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7669 - loss: 1.3702 - val_accuracy: 0.6401 - val_loss: 1.4553 - learning_rate: 5.0000e-04
# Epoch 70/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7535 - loss: 1.5114 - val_accuracy: 0.6564 - val_loss: 1.3970 - learning_rate: 5.0000e-04
# Epoch 71/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7758 - loss: 1.2969 - val_accuracy: 0.6800 - val_loss: 1.3588 - learning_rate: 5.0000e-04
# Epoch 72/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7528 - loss: 1.5148
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7527 - loss: 1.5149 - val_accuracy: 0.6158 - val_loss: 1.5117 - learning_rate: 5.0000e-04
# Epoch 73/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.7638 - loss: 1.4369 - val_accuracy: 0.7081 - val_loss: 1.2503 - learning_rate: 2.5000e-04
# Epoch 74/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8010 - loss: 1.4222 - val_accuracy: 0.6885 - val_loss: 1.2786 - learning_rate: 2.5000e-04
# Epoch 75/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.8521 - loss: 1.1974 - val_accuracy: 0.6708 - val_loss: 1.3687 - learning_rate: 2.5000e-04
# Epoch 76/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.8165 - loss: 1.3415 - val_accuracy: 0.6983 - val_loss: 1.2661 - learning_rate: 2.5000e-04
# Epoch 77/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.8395 - loss: 1.2781 - val_accuracy: 0.6623 - val_loss: 1.3986 - learning_rate: 2.5000e-04
# Epoch 78/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.8383 - loss: 1.2026 - val_accuracy: 0.6970 - val_loss: 1.2747 - learning_rate: 2.5000e-04
# Epoch 79/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8219 - loss: 1.2704 - val_accuracy: 0.6649 - val_loss: 1.3471 - learning_rate: 2.5000e-04
# Epoch 80/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.8203 - loss: 1.2944 - val_accuracy: 0.7075 - val_loss: 1.2254 - learning_rate: 2.5000e-04
# Epoch 81/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.8270 - loss: 1.2550 - val_accuracy: 0.6970 - val_loss: 1.2229 - learning_rate: 2.5000e-04
# Epoch 82/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8086 - loss: 1.3097 - val_accuracy: 0.6780 - val_loss: 1.2825 - learning_rate: 2.5000e-04
# Epoch 83/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8365 - loss: 1.3077 - val_accuracy: 0.7003 - val_loss: 1.2259 - learning_rate: 2.5000e-04
# Epoch 84/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.8476 - loss: 1.1588 - val_accuracy: 0.6584 - val_loss: 1.3250 - learning_rate: 2.5000e-04
# Epoch 85/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7992 - loss: 1.3523 - val_accuracy: 0.6983 - val_loss: 1.2363 - learning_rate: 2.5000e-04
# Epoch 86/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8786 - loss: 1.0716 - val_accuracy: 0.6904 - val_loss: 1.2761 - learning_rate: 2.5000e-04
# Epoch 87/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8416 - loss: 1.1896 - val_accuracy: 0.6813 - val_loss: 1.3268 - learning_rate: 2.5000e-04
# Epoch 88/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8487 - loss: 1.1864 - val_accuracy: 0.7120 - val_loss: 1.2020 - learning_rate: 2.5000e-04
# Epoch 89/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8205 - loss: 1.2978 - val_accuracy: 0.6846 - val_loss: 1.2948 - learning_rate: 2.5000e-04
# Epoch 90/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8598 - loss: 1.1791 - val_accuracy: 0.6865 - val_loss: 1.2796 - learning_rate: 2.5000e-04
# Epoch 91/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8589 - loss: 1.0839 - val_accuracy: 0.6669 - val_loss: 1.3434 - learning_rate: 2.5000e-04
# Epoch 92/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8796 - loss: 1.1021 - val_accuracy: 0.6348 - val_loss: 1.3824 - learning_rate: 2.5000e-04
# Epoch 93/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8542 - loss: 1.1955 - val_accuracy: 0.6754 - val_loss: 1.3246 - learning_rate: 2.5000e-04
# Epoch 94/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8659 - loss: 1.1211 - val_accuracy: 0.6198 - val_loss: 1.4763 - learning_rate: 2.5000e-04
# Epoch 95/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8406 - loss: 1.2409 - val_accuracy: 0.6859 - val_loss: 1.2710 - learning_rate: 2.5000e-04
# Epoch 96/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.8656 - loss: 1.1477 - val_accuracy: 0.6459 - val_loss: 1.3767 - learning_rate: 2.5000e-04
# Epoch 97/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8766 - loss: 1.1238 - val_accuracy: 0.6708 - val_loss: 1.2936 - learning_rate: 2.5000e-04
# Epoch 98/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8712 - loss: 1.0502 - val_accuracy: 0.6832 - val_loss: 1.2807 - learning_rate: 2.5000e-04
# Epoch 99/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8821 - loss: 1.0870 - val_accuracy: 0.6950 - val_loss: 1.2564 - learning_rate: 2.5000e-04
# Epoch 100/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.8810 - loss: 1.1597 - val_accuracy: 0.6990 - val_loss: 1.2515 - learning_rate: 2.5000e-04
# Epoch 101/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8868 - loss: 1.0571 - val_accuracy: 0.6741 - val_loss: 1.3714 - learning_rate: 2.5000e-04
# Epoch 102/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8584 - loss: 1.1832 - val_accuracy: 0.6243 - val_loss: 1.5483 - learning_rate: 2.5000e-04
# Epoch 103/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8525 - loss: 1.3070 - val_accuracy: 0.6473 - val_loss: 1.3952 - learning_rate: 2.5000e-04
# Epoch 104/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8833 - loss: 1.1081 - val_accuracy: 0.6211 - val_loss: 1.4808 - learning_rate: 2.5000e-04
# Epoch 105/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8504 - loss: 1.2003 - val_accuracy: 0.6924 - val_loss: 1.2782 - learning_rate: 2.5000e-04
# Epoch 106/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.8376 - loss: 1.1913 - val_accuracy: 0.6643 - val_loss: 1.3667 - learning_rate: 2.5000e-04
# Epoch 107/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8859 - loss: 1.1299 - val_accuracy: 0.6793 - val_loss: 1.3190 - learning_rate: 2.5000e-04
# Epoch 108/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8765 - loss: 1.1592
# Epoch 108: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8765 - loss: 1.1587 - val_accuracy: 0.6597 - val_loss: 1.3397 - learning_rate: 2.5000e-04
# Epoch 109/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8726 - loss: 1.1496 - val_accuracy: 0.6918 - val_loss: 1.2907 - learning_rate: 1.2500e-04
# Epoch 110/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8204 - loss: 1.2920 - val_accuracy: 0.6970 - val_loss: 1.2244 - learning_rate: 1.2500e-04
# Epoch 111/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8912 - loss: 1.0583 - val_accuracy: 0.6911 - val_loss: 1.2751 - learning_rate: 1.2500e-04
# Epoch 112/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8667 - loss: 1.1932 - val_accuracy: 0.7140 - val_loss: 1.2151 - learning_rate: 1.2500e-04
# Epoch 113/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9015 - loss: 1.1248 - val_accuracy: 0.7094 - val_loss: 1.2386 - learning_rate: 1.2500e-04
# Epoch 114/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8986 - loss: 1.0836 - val_accuracy: 0.7042 - val_loss: 1.2533 - learning_rate: 1.2500e-04
# Epoch 115/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8977 - loss: 1.0749 - val_accuracy: 0.6891 - val_loss: 1.2428 - learning_rate: 1.2500e-04
# Epoch 116/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.9044 - loss: 1.0693 - val_accuracy: 0.7048 - val_loss: 1.2270 - learning_rate: 1.2500e-04
# Epoch 117/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.8915 - loss: 1.0795 - val_accuracy: 0.6990 - val_loss: 1.2343 - learning_rate: 1.2500e-04
# Epoch 118/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.9164 - loss: 0.9889 - val_accuracy: 0.6872 - val_loss: 1.2735 - learning_rate: 1.2500e-04
# Epoch 119/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.9226 - loss: 0.9246 - val_accuracy: 0.6832 - val_loss: 1.2712 - learning_rate: 1.2500e-04
# Epoch 120/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8956 - loss: 1.0478 - val_accuracy: 0.6976 - val_loss: 1.2090 - learning_rate: 1.2500e-04
# Epoch 121/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.9148 - loss: 1.0075 - val_accuracy: 0.7068 - val_loss: 1.2234 - learning_rate: 1.2500e-04
# Epoch 122/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9363 - loss: 0.9312 - val_accuracy: 0.6872 - val_loss: 1.2685 - learning_rate: 1.2500e-04
# Epoch 123/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8997 - loss: 1.0391 - val_accuracy: 0.7009 - val_loss: 1.2160 - learning_rate: 1.2500e-04
# Epoch 124/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9288 - loss: 0.9356 - val_accuracy: 0.6806 - val_loss: 1.2962 - learning_rate: 1.2500e-04
# Epoch 125/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9005 - loss: 0.9734 - val_accuracy: 0.6996 - val_loss: 1.2337 - learning_rate: 1.2500e-04
# Epoch 126/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9294 - loss: 0.9223 - val_accuracy: 0.6832 - val_loss: 1.2614 - learning_rate: 1.2500e-04
# Epoch 127/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9058 - loss: 1.0891 - val_accuracy: 0.6924 - val_loss: 1.2376 - learning_rate: 1.2500e-04
# Epoch 128/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8861 - loss: 1.0146 - val_accuracy: 0.6970 - val_loss: 1.2329 - learning_rate: 1.2500e-04
# Epoch 129/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9046 - loss: 1.0740 - val_accuracy: 0.6911 - val_loss: 1.2461 - learning_rate: 1.2500e-04
# Epoch 130/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9168 - loss: 0.9253 - val_accuracy: 0.6793 - val_loss: 1.3177 - learning_rate: 1.2500e-04
# Epoch 131/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8960 - loss: 1.0409 - val_accuracy: 0.7042 - val_loss: 1.2122 - learning_rate: 1.2500e-04
# Epoch 132/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8942 - loss: 1.1460
# Epoch 132: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8942 - loss: 1.1454 - val_accuracy: 0.7048 - val_loss: 1.2464 - learning_rate: 1.2500e-04
# Epoch 133/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9259 - loss: 0.9036 - val_accuracy: 0.7055 - val_loss: 1.2135 - learning_rate: 6.2500e-05
# Epoch 134/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9143 - loss: 1.0656 - val_accuracy: 0.7035 - val_loss: 1.1928 - learning_rate: 6.2500e-05
# Epoch 135/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8925 - loss: 1.0876 - val_accuracy: 0.7042 - val_loss: 1.2191 - learning_rate: 6.2500e-05
# Epoch 136/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9480 - loss: 0.9047 - val_accuracy: 0.7127 - val_loss: 1.1757 - learning_rate: 6.2500e-05
# Epoch 137/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9078 - loss: 0.9497 - val_accuracy: 0.7042 - val_loss: 1.1945 - learning_rate: 6.2500e-05
# Epoch 138/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9003 - loss: 1.0653 - val_accuracy: 0.7062 - val_loss: 1.2166 - learning_rate: 6.2500e-05
# Epoch 139/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9025 - loss: 0.9916 - val_accuracy: 0.7029 - val_loss: 1.1853 - learning_rate: 6.2500e-05
# Epoch 140/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.8966 - loss: 1.0875 - val_accuracy: 0.7042 - val_loss: 1.2043 - learning_rate: 6.2500e-05
# Epoch 141/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9040 - loss: 1.0919 - val_accuracy: 0.7075 - val_loss: 1.1941 - learning_rate: 6.2500e-05
# Epoch 142/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9256 - loss: 0.9406 - val_accuracy: 0.7075 - val_loss: 1.2036 - learning_rate: 6.2500e-05
# Epoch 143/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.9362 - loss: 0.9244 - val_accuracy: 0.7114 - val_loss: 1.1831 - learning_rate: 6.2500e-05
# Epoch 144/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.8747 - loss: 1.0658 - val_accuracy: 0.7016 - val_loss: 1.2061 - learning_rate: 6.2500e-05
# Epoch 145/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8985 - loss: 1.0474 - val_accuracy: 0.6839 - val_loss: 1.2648 - learning_rate: 6.2500e-05
# Epoch 146/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8994 - loss: 0.9725 - val_accuracy: 0.7192 - val_loss: 1.1753 - learning_rate: 6.2500e-05
# Epoch 147/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9328 - loss: 0.9379 - val_accuracy: 0.6754 - val_loss: 1.2879 - learning_rate: 6.2500e-05
# Epoch 148/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9012 - loss: 1.0172 - val_accuracy: 0.7042 - val_loss: 1.1817 - learning_rate: 6.2500e-05
# Epoch 149/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9366 - loss: 0.9037 - val_accuracy: 0.7107 - val_loss: 1.1898 - learning_rate: 6.2500e-05
# Epoch 150/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9078 - loss: 1.0319 - val_accuracy: 0.7068 - val_loss: 1.1815 - learning_rate: 6.2500e-05
# Epoch 151/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9144 - loss: 0.9307 - val_accuracy: 0.7094 - val_loss: 1.2125 - learning_rate: 6.2500e-05
# Epoch 152/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9326 - loss: 0.9211 - val_accuracy: 0.6976 - val_loss: 1.2300 - learning_rate: 6.2500e-05
# Epoch 153/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9080 - loss: 0.9820 - val_accuracy: 0.6904 - val_loss: 1.2565 - learning_rate: 6.2500e-05
# Epoch 154/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9282 - loss: 0.8959 - val_accuracy: 0.7081 - val_loss: 1.1730 - learning_rate: 6.2500e-05
# Epoch 155/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9181 - loss: 0.9252 - val_accuracy: 0.7029 - val_loss: 1.2051 - learning_rate: 6.2500e-05
# Epoch 156/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8926 - loss: 1.0612 - val_accuracy: 0.7147 - val_loss: 1.1716 - learning_rate: 6.2500e-05
# Epoch 157/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8860 - loss: 1.0519 - val_accuracy: 0.7153 - val_loss: 1.1720 - learning_rate: 6.2500e-05
# Epoch 158/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9105 - loss: 1.0126 - val_accuracy: 0.7009 - val_loss: 1.2191 - learning_rate: 6.2500e-05
# Epoch 159/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8567 - loss: 1.0874 - val_accuracy: 0.7029 - val_loss: 1.1996 - learning_rate: 6.2500e-05
# Epoch 160/160
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9166 - loss: 0.9849 - val_accuracy: 0.7147 - val_loss: 1.1494 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 146.
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# Fold 1 - Accuracy: 0.7192, F1-macro: 0.7608
#
# Fold 2/5
# Train: 6519, Val: 1632
# Epoch 1/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 16s 84ms/step - accuracy: 0.0952 - loss: 9.8779 - val_accuracy: 0.2138 - val_loss: 8.3714 - learning_rate: 5.0000e-04
# Epoch 2/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.2046 - loss: 7.9595 - val_accuracy: 0.3015 - val_loss: 6.8623 - learning_rate: 5.0000e-04
# Epoch 3/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.3141 - loss: 6.6270 - val_accuracy: 0.3836 - val_loss: 5.7848 - learning_rate: 5.0000e-04
# Epoch 4/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.3441 - loss: 5.8096 - val_accuracy: 0.3836 - val_loss: 5.0676 - learning_rate: 5.0000e-04
# Epoch 5/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.3646 - loss: 5.1617 - val_accuracy: 0.4596 - val_loss: 4.4637 - learning_rate: 5.0000e-04
# Epoch 6/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.4032 - loss: 4.6029 - val_accuracy: 0.4712 - val_loss: 3.9832 - learning_rate: 5.0000e-04
# Epoch 7/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.4420 - loss: 4.1758 - val_accuracy: 0.5159 - val_loss: 3.5856 - learning_rate: 5.0000e-04
# Epoch 8/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.4784 - loss: 3.7516 - val_accuracy: 0.4994 - val_loss: 3.3931 - learning_rate: 5.0000e-04
# Epoch 9/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.4787 - loss: 3.5281 - val_accuracy: 0.5625 - val_loss: 3.0290 - learning_rate: 5.0000e-04
# Epoch 10/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.4981 - loss: 3.2850 - val_accuracy: 0.4565 - val_loss: 3.0982 - learning_rate: 5.0000e-04
# Epoch 11/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.5310 - loss: 3.0345 - val_accuracy: 0.5404 - val_loss: 2.7075 - learning_rate: 5.0000e-04
# Epoch 12/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.5490 - loss: 2.8535 - val_accuracy: 0.4737 - val_loss: 2.7565 - learning_rate: 5.0000e-04
# Epoch 13/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.5539 - loss: 2.7790 - val_accuracy: 0.5074 - val_loss: 2.5666 - learning_rate: 5.0000e-04
# Epoch 14/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.5778 - loss: 2.4637 - val_accuracy: 0.4896 - val_loss: 2.5322 - learning_rate: 5.0000e-04
# Epoch 15/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.5904 - loss: 2.3957 - val_accuracy: 0.4804 - val_loss: 2.4556 - learning_rate: 5.0000e-04
# Epoch 16/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.5827 - loss: 2.3770 - val_accuracy: 0.5080 - val_loss: 2.3327 - learning_rate: 5.0000e-04
# Epoch 17/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.5860 - loss: 2.3668 - val_accuracy: 0.5852 - val_loss: 2.0812 - learning_rate: 5.0000e-04
# Epoch 18/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6044 - loss: 2.1988 - val_accuracy: 0.5502 - val_loss: 2.1663 - learning_rate: 5.0000e-04
# Epoch 19/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6172 - loss: 2.0651 - val_accuracy: 0.5588 - val_loss: 2.0296 - learning_rate: 5.0000e-04
# Epoch 20/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6019 - loss: 2.1646 - val_accuracy: 0.5306 - val_loss: 2.0515 - learning_rate: 5.0000e-04
# Epoch 21/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6238 - loss: 2.0083 - val_accuracy: 0.5055 - val_loss: 2.0861 - learning_rate: 5.0000e-04
# Epoch 22/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6385 - loss: 1.8291 - val_accuracy: 0.5355 - val_loss: 1.9675 - learning_rate: 5.0000e-04
# Epoch 23/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6326 - loss: 1.8713 - val_accuracy: 0.5331 - val_loss: 1.9267 - learning_rate: 5.0000e-04
# Epoch 24/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6191 - loss: 1.9564 - val_accuracy: 0.5913 - val_loss: 1.7778 - learning_rate: 5.0000e-04
# Epoch 25/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6236 - loss: 1.8908 - val_accuracy: 0.5460 - val_loss: 1.8677 - learning_rate: 5.0000e-04
# Epoch 26/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6316 - loss: 1.8948 - val_accuracy: 0.4663 - val_loss: 2.0713 - learning_rate: 5.0000e-04
# Epoch 27/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6643 - loss: 1.7385 - val_accuracy: 0.5864 - val_loss: 1.7771 - learning_rate: 5.0000e-04
# Epoch 28/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.6513 - loss: 1.8274 - val_accuracy: 0.5827 - val_loss: 1.7251 - learning_rate: 5.0000e-04
# Epoch 29/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6494 - loss: 1.8296 - val_accuracy: 0.5772 - val_loss: 1.7915 - learning_rate: 5.0000e-04
# Epoch 30/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6554 - loss: 1.7266 - val_accuracy: 0.4859 - val_loss: 2.1057 - learning_rate: 5.0000e-04
# Epoch 31/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6581 - loss: 1.7125 - val_accuracy: 0.5650 - val_loss: 1.7115 - learning_rate: 5.0000e-04
# Epoch 32/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6904 - loss: 1.5660 - val_accuracy: 0.5533 - val_loss: 1.7999 - learning_rate: 5.0000e-04
# Epoch 33/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6877 - loss: 1.4901 - val_accuracy: 0.5968 - val_loss: 1.6608 - learning_rate: 5.0000e-04
# Epoch 34/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6878 - loss: 1.6652 - val_accuracy: 0.4828 - val_loss: 1.9870 - learning_rate: 5.0000e-04
# Epoch 35/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6870 - loss: 1.6097 - val_accuracy: 0.5674 - val_loss: 1.6933 - learning_rate: 5.0000e-04
# Epoch 36/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7030 - loss: 1.5479 - val_accuracy: 0.5680 - val_loss: 1.7718 - learning_rate: 5.0000e-04
# Epoch 37/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7007 - loss: 1.5632 - val_accuracy: 0.4902 - val_loss: 1.9470 - learning_rate: 5.0000e-04
# Epoch 38/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6920 - loss: 1.5767 - val_accuracy: 0.5184 - val_loss: 1.9397 - learning_rate: 5.0000e-04
# Epoch 39/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6996 - loss: 1.4677 - val_accuracy: 0.5809 - val_loss: 1.6327 - learning_rate: 5.0000e-04
# Epoch 40/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6984 - loss: 1.6893 - val_accuracy: 0.5110 - val_loss: 1.8443 - learning_rate: 5.0000e-04
# Epoch 41/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6936 - loss: 1.5695 - val_accuracy: 0.6011 - val_loss: 1.5893 - learning_rate: 5.0000e-04
# Epoch 42/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7179 - loss: 1.4699 - val_accuracy: 0.5870 - val_loss: 1.6443 - learning_rate: 5.0000e-04
# Epoch 43/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7291 - loss: 1.4834 - val_accuracy: 0.5539 - val_loss: 1.7184 - learning_rate: 5.0000e-04
# Epoch 44/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7327 - loss: 1.4439 - val_accuracy: 0.5435 - val_loss: 1.8111 - learning_rate: 5.0000e-04
# Epoch 45/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7141 - loss: 1.5866 - val_accuracy: 0.5159 - val_loss: 1.9021 - learning_rate: 5.0000e-04
# Epoch 46/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7055 - loss: 1.5645 - val_accuracy: 0.4847 - val_loss: 1.9863 - learning_rate: 5.0000e-04
# Epoch 47/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7361 - loss: 1.4849 - val_accuracy: 0.4571 - val_loss: 2.0818 - learning_rate: 5.0000e-04
# Epoch 48/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7389 - loss: 1.4514 - val_accuracy: 0.6097 - val_loss: 1.5532 - learning_rate: 5.0000e-04
# Epoch 49/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7821 - loss: 1.3024 - val_accuracy: 0.6127 - val_loss: 1.5868 - learning_rate: 5.0000e-04
# Epoch 50/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7594 - loss: 1.4505 - val_accuracy: 0.4835 - val_loss: 1.9821 - learning_rate: 5.0000e-04
# Epoch 51/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.7399 - loss: 1.4811 - val_accuracy: 0.5306 - val_loss: 1.7957 - learning_rate: 5.0000e-04
# Epoch 52/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.7527 - loss: 1.4477 - val_accuracy: 0.5705 - val_loss: 1.7309 - learning_rate: 5.0000e-04
# Epoch 53/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7488 - loss: 1.4418 - val_accuracy: 0.5104 - val_loss: 1.8560 - learning_rate: 5.0000e-04
# Epoch 54/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7521 - loss: 1.5628 - val_accuracy: 0.5797 - val_loss: 1.6992 - learning_rate: 5.0000e-04
# Epoch 55/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7654 - loss: 1.4163 - val_accuracy: 0.5692 - val_loss: 1.7307 - learning_rate: 5.0000e-04
# Epoch 56/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7264 - loss: 1.4857 - val_accuracy: 0.5895 - val_loss: 1.6292 - learning_rate: 5.0000e-04
# Epoch 57/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.7846 - loss: 1.3549 - val_accuracy: 0.5165 - val_loss: 1.9032 - learning_rate: 5.0000e-04
# Epoch 58/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.7714 - loss: 1.4020 - val_accuracy: 0.5735 - val_loss: 1.6971 - learning_rate: 5.0000e-04
# Epoch 59/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7736 - loss: 1.4554 - val_accuracy: 0.6023 - val_loss: 1.6241 - learning_rate: 5.0000e-04
# Epoch 60/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7364 - loss: 1.5011 - val_accuracy: 0.4485 - val_loss: 2.1434 - learning_rate: 5.0000e-04
# Epoch 61/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7643 - loss: 1.4778 - val_accuracy: 0.6085 - val_loss: 1.5666 - learning_rate: 5.0000e-04
# Epoch 62/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7630 - loss: 1.3973 - val_accuracy: 0.5545 - val_loss: 1.7718 - learning_rate: 5.0000e-04
# Epoch 63/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7652 - loss: 1.4600 - val_accuracy: 0.5784 - val_loss: 1.7314 - learning_rate: 5.0000e-04
# Epoch 64/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7936 - loss: 1.3494 - val_accuracy: 0.5938 - val_loss: 1.6224 - learning_rate: 5.0000e-04
# Epoch 65/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7633 - loss: 1.4006 - val_accuracy: 0.6311 - val_loss: 1.5153 - learning_rate: 5.0000e-04
# Epoch 66/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7443 - loss: 1.5346 - val_accuracy: 0.5631 - val_loss: 1.6745 - learning_rate: 5.0000e-04
# Epoch 67/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7993 - loss: 1.2995 - val_accuracy: 0.5668 - val_loss: 1.7347 - learning_rate: 5.0000e-04
# Epoch 68/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7960 - loss: 1.2619 - val_accuracy: 0.6195 - val_loss: 1.5074 - learning_rate: 5.0000e-04
# Epoch 69/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7538 - loss: 1.4114 - val_accuracy: 0.5760 - val_loss: 1.6941 - learning_rate: 5.0000e-04
# Epoch 70/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7451 - loss: 1.5023 - val_accuracy: 0.6078 - val_loss: 1.5865 - learning_rate: 5.0000e-04
# Epoch 71/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7875 - loss: 1.3310 - val_accuracy: 0.6054 - val_loss: 1.5554 - learning_rate: 5.0000e-04
# Epoch 72/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8182 - loss: 1.3052 - val_accuracy: 0.5380 - val_loss: 1.8373 - learning_rate: 5.0000e-04
# Epoch 73/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7799 - loss: 1.3314 - val_accuracy: 0.5521 - val_loss: 1.7400 - learning_rate: 5.0000e-04
# Epoch 74/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7853 - loss: 1.3566 - val_accuracy: 0.6103 - val_loss: 1.5595 - learning_rate: 5.0000e-04
# Epoch 75/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7757 - loss: 1.4524 - val_accuracy: 0.5374 - val_loss: 1.9091 - learning_rate: 5.0000e-04
# Epoch 76/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7778 - loss: 1.3406 - val_accuracy: 0.5778 - val_loss: 1.7040 - learning_rate: 5.0000e-04
# Epoch 77/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7854 - loss: 1.3737 - val_accuracy: 0.6281 - val_loss: 1.5151 - learning_rate: 5.0000e-04
# Epoch 78/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8339 - loss: 1.2756 - val_accuracy: 0.5772 - val_loss: 1.6608 - learning_rate: 5.0000e-04
# Epoch 79/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.7891 - loss: 1.4632 - val_accuracy: 0.6029 - val_loss: 1.5674 - learning_rate: 5.0000e-04
# Epoch 80/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8025 - loss: 1.3719 - val_accuracy: 0.6207 - val_loss: 1.5461 - learning_rate: 5.0000e-04
# Epoch 81/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.7967 - loss: 1.3449 - val_accuracy: 0.5570 - val_loss: 1.7186 - learning_rate: 5.0000e-04
# Epoch 82/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8045 - loss: 1.2938 - val_accuracy: 0.5839 - val_loss: 1.6491 - learning_rate: 5.0000e-04
# Epoch 83/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7953 - loss: 1.3320 - val_accuracy: 0.6397 - val_loss: 1.4652 - learning_rate: 5.0000e-04
# Epoch 84/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8225 - loss: 1.2565 - val_accuracy: 0.5472 - val_loss: 1.9355 - learning_rate: 5.0000e-04
# Epoch 85/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.7709 - loss: 1.4796 - val_accuracy: 0.5980 - val_loss: 1.6476 - learning_rate: 5.0000e-04
# Epoch 86/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8118 - loss: 1.3043 - val_accuracy: 0.5846 - val_loss: 1.6941 - learning_rate: 5.0000e-04
# Epoch 87/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8020 - loss: 1.3754 - val_accuracy: 0.5938 - val_loss: 1.6426 - learning_rate: 5.0000e-04
# Epoch 88/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7888 - loss: 1.4552 - val_accuracy: 0.6029 - val_loss: 1.6005 - learning_rate: 5.0000e-04
# Epoch 89/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.7843 - loss: 1.4343 - val_accuracy: 0.5729 - val_loss: 1.7309 - learning_rate: 5.0000e-04
# Epoch 90/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8011 - loss: 1.4261 - val_accuracy: 0.5551 - val_loss: 1.8274 - learning_rate: 5.0000e-04
# Epoch 91/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8248 - loss: 1.3058 - val_accuracy: 0.5312 - val_loss: 1.9190 - learning_rate: 5.0000e-04
# Epoch 92/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8293 - loss: 1.2506 - val_accuracy: 0.5699 - val_loss: 1.6634 - learning_rate: 5.0000e-04
# Epoch 93/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.8335 - loss: 1.2469 - val_accuracy: 0.6060 - val_loss: 1.5966 - learning_rate: 5.0000e-04
# Epoch 94/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.7754 - loss: 1.4059 - val_accuracy: 0.6140 - val_loss: 1.5995 - learning_rate: 5.0000e-04
# Epoch 95/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8228 - loss: 1.3485 - val_accuracy: 0.6115 - val_loss: 1.5705 - learning_rate: 5.0000e-04
# Epoch 96/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8392 - loss: 1.3001 - val_accuracy: 0.5692 - val_loss: 1.7721 - learning_rate: 5.0000e-04
# Epoch 97/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8097 - loss: 1.3742 - val_accuracy: 0.5919 - val_loss: 1.6318 - learning_rate: 5.0000e-04
# Epoch 98/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8199 - loss: 1.2374 - val_accuracy: 0.5876 - val_loss: 1.6782 - learning_rate: 5.0000e-04
# Epoch 99/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8116 - loss: 1.3444 - val_accuracy: 0.5962 - val_loss: 1.6650 - learning_rate: 5.0000e-04
# Epoch 100/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8492 - loss: 1.1630 - val_accuracy: 0.5919 - val_loss: 1.6291 - learning_rate: 5.0000e-04
# Epoch 101/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8012 - loss: 1.4767 - val_accuracy: 0.5852 - val_loss: 1.6899 - learning_rate: 5.0000e-04
# Epoch 102/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8454 - loss: 1.2172 - val_accuracy: 0.5913 - val_loss: 1.7005 - learning_rate: 5.0000e-04
# Epoch 103/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7844 - loss: 1.4917
# Epoch 103: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.7846 - loss: 1.4906 - val_accuracy: 0.5202 - val_loss: 2.0521 - learning_rate: 5.0000e-04
# Epoch 104/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.8540 - loss: 1.2428 - val_accuracy: 0.6409 - val_loss: 1.5158 - learning_rate: 2.5000e-04
# Epoch 105/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8738 - loss: 1.1746 - val_accuracy: 0.6336 - val_loss: 1.5180 - learning_rate: 2.5000e-04
# Epoch 106/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8616 - loss: 1.1547 - val_accuracy: 0.6164 - val_loss: 1.5339 - learning_rate: 2.5000e-04
# Epoch 107/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.8607 - loss: 1.2591 - val_accuracy: 0.6250 - val_loss: 1.5592 - learning_rate: 2.5000e-04
# Epoch 108/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8684 - loss: 1.1142 - val_accuracy: 0.6409 - val_loss: 1.4681 - learning_rate: 2.5000e-04
# Epoch 109/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8866 - loss: 1.1194 - val_accuracy: 0.6299 - val_loss: 1.5133 - learning_rate: 2.5000e-04
# Epoch 110/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8933 - loss: 1.1087 - val_accuracy: 0.6311 - val_loss: 1.5146 - learning_rate: 2.5000e-04
# Epoch 111/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8528 - loss: 1.2059 - val_accuracy: 0.5938 - val_loss: 1.6139 - learning_rate: 2.5000e-04
# Epoch 112/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8669 - loss: 1.1957 - val_accuracy: 0.6275 - val_loss: 1.4725 - learning_rate: 2.5000e-04
# Epoch 113/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8905 - loss: 1.0450 - val_accuracy: 0.6054 - val_loss: 1.5984 - learning_rate: 2.5000e-04
# Epoch 114/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8688 - loss: 1.1121 - val_accuracy: 0.6397 - val_loss: 1.5095 - learning_rate: 2.5000e-04
# Epoch 115/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8638 - loss: 1.1715 - val_accuracy: 0.6176 - val_loss: 1.5621 - learning_rate: 2.5000e-04
# Epoch 116/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8959 - loss: 1.0277 - val_accuracy: 0.5864 - val_loss: 1.6457 - learning_rate: 2.5000e-04
# Epoch 117/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8906 - loss: 0.9940 - val_accuracy: 0.6017 - val_loss: 1.5801 - learning_rate: 2.5000e-04
# Epoch 118/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8523 - loss: 1.2443 - val_accuracy: 0.6091 - val_loss: 1.6221 - learning_rate: 2.5000e-04
# Epoch 119/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8780 - loss: 1.1099 - val_accuracy: 0.5907 - val_loss: 1.6635 - learning_rate: 2.5000e-04
# Epoch 120/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8972 - loss: 0.9525 - val_accuracy: 0.6115 - val_loss: 1.5738 - learning_rate: 2.5000e-04
# Epoch 121/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8394 - loss: 1.2904 - val_accuracy: 0.6183 - val_loss: 1.5645 - learning_rate: 2.5000e-04
# Epoch 122/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8353 - loss: 1.2704 - val_accuracy: 0.6140 - val_loss: 1.5268 - learning_rate: 2.5000e-04
# Epoch 123/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8910 - loss: 1.0881 - val_accuracy: 0.6195 - val_loss: 1.5456 - learning_rate: 2.5000e-04
# Epoch 124/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8929 - loss: 1.0775
# Epoch 124: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8930 - loss: 1.0769 - val_accuracy: 0.6183 - val_loss: 1.5806 - learning_rate: 2.5000e-04
# Epoch 125/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.8979 - loss: 1.0866 - val_accuracy: 0.6366 - val_loss: 1.4882 - learning_rate: 1.2500e-04
# Epoch 126/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8815 - loss: 1.1397 - val_accuracy: 0.6373 - val_loss: 1.4660 - learning_rate: 1.2500e-04
# Epoch 127/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9001 - loss: 1.0177 - val_accuracy: 0.6232 - val_loss: 1.5149 - learning_rate: 1.2500e-04
# Epoch 128/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8880 - loss: 1.0749 - val_accuracy: 0.6299 - val_loss: 1.4565 - learning_rate: 1.2500e-04
# Epoch 129/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.9062 - loss: 1.0022 - val_accuracy: 0.6458 - val_loss: 1.4255 - learning_rate: 1.2500e-04
# Epoch 130/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8854 - loss: 1.0211 - val_accuracy: 0.6556 - val_loss: 1.4427 - learning_rate: 1.2500e-04
# Epoch 131/160
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9397 - loss: 0.8477 - val_accuracy: 0.6495 - val_loss: 1.4612 - learning_rate: 1.2500e-04
# Epoch 132/160
# ...
# Epoch 32/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.6629 - loss: 1.6682 - val_accuracy: 0.5606 - val_loss: 1.7577 - learning_rate: 5.0000e-04
# Epoch 33/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.6617 - loss: 1.7057 - val_accuracy: 0.5554 - val_loss: 1.8171 - learning_rate: 5.0000e-04
# Epoch 34/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.6720 - loss: 1.7110 - val_accuracy: 0.5369 - val_loss: 1.8377 - learning_rate: 5.0000e-04
# Epoch 35/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.6571 - loss: 1.7310 - val_accuracy: 0.6015 - val_loss: 1.6847 - learning_rate: 5.0000e-04
# Epoch 36/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.7055 - loss: 1.5498 - val_accuracy: 0.5536 - val_loss: 1.7666 - learning_rate: 5.0000e-04
# Epoch 37/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.6976 - loss: 1.6937 - val_accuracy: 0.5767 - val_loss: 1.7089 - learning_rate: 5.0000e-04
# Epoch 38/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.6797 - loss: 1.5829 - val_accuracy: 0.4971 - val_loss: 1.9254 - learning_rate: 5.0000e-04
# Epoch 39/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.6530 - loss: 1.6914 - val_accuracy: 0.5692 - val_loss: 1.6865 - learning_rate: 5.0000e-04
# Epoch 40/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.6813 - loss: 1.6820 - val_accuracy: 0.4083 - val_loss: 2.1763 - learning_rate: 5.0000e-04
# Epoch 41/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.6735 - loss: 1.6232 - val_accuracy: 0.5721 - val_loss: 1.7176 - learning_rate: 5.0000e-04
# Epoch 42/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.6969 - loss: 1.6271 - val_accuracy: 0.5882 - val_loss: 1.6295 - learning_rate: 5.0000e-04
# Epoch 43/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.7251 - loss: 1.4476 - val_accuracy: 0.5513 - val_loss: 1.7967 - learning_rate: 5.0000e-04
# Epoch 44/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.6834 - loss: 1.6867 - val_accuracy: 0.5358 - val_loss: 1.8299 - learning_rate: 5.0000e-04
# Epoch 45/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7014 - loss: 1.5807 - val_accuracy: 0.5859 - val_loss: 1.6649 - learning_rate: 5.0000e-04
# Epoch 46/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7116 - loss: 1.5445 - val_accuracy: 0.5496 - val_loss: 1.7426 - learning_rate: 5.0000e-04
# Epoch 47/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.7128 - loss: 1.5524 - val_accuracy: 0.5554 - val_loss: 1.7268 - learning_rate: 5.0000e-04
# Epoch 48/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.7109 - loss: 1.5632 - val_accuracy: 0.5744 - val_loss: 1.6594 - learning_rate: 5.0000e-04
# Epoch 49/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6952 - loss: 1.5778 - val_accuracy: 0.5888 - val_loss: 1.6023 - learning_rate: 5.0000e-04
# Epoch 50/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.7466 - loss: 1.4109 - val_accuracy: 0.5727 - val_loss: 1.6578 - learning_rate: 5.0000e-04
# Epoch 51/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.7511 - loss: 1.3844 - val_accuracy: 0.5565 - val_loss: 1.7447 - learning_rate: 5.0000e-04
# Epoch 52/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.7213 - loss: 1.5060 - val_accuracy: 0.5536 - val_loss: 1.7729 - learning_rate: 5.0000e-04
# Epoch 53/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7315 - loss: 1.5448 - val_accuracy: 0.6113 - val_loss: 1.5562 - learning_rate: 5.0000e-04
# Epoch 54/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7307 - loss: 1.3874 - val_accuracy: 0.6044 - val_loss: 1.5819 - learning_rate: 5.0000e-04
# Epoch 55/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7520 - loss: 1.3907 - val_accuracy: 0.5905 - val_loss: 1.6509 - learning_rate: 5.0000e-04
# Epoch 56/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7665 - loss: 1.3180 - val_accuracy: 0.5657 - val_loss: 1.7554 - learning_rate: 5.0000e-04
# Epoch 57/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7433 - loss: 1.4770 - val_accuracy: 0.5606 - val_loss: 1.7495 - learning_rate: 5.0000e-04
# Epoch 58/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.7553 - loss: 1.4339 - val_accuracy: 0.5923 - val_loss: 1.6386 - learning_rate: 5.0000e-04
# Epoch 59/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.7524 - loss: 1.4221 - val_accuracy: 0.4821 - val_loss: 1.9839 - learning_rate: 5.0000e-04
# Epoch 60/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.7356 - loss: 1.5220 - val_accuracy: 0.6113 - val_loss: 1.5732 - learning_rate: 5.0000e-04
# Epoch 61/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.7552 - loss: 1.4334 - val_accuracy: 0.5940 - val_loss: 1.6310 - learning_rate: 5.0000e-04
# Epoch 62/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.7493 - loss: 1.4662 - val_accuracy: 0.6061 - val_loss: 1.5478 - learning_rate: 5.0000e-04
# Epoch 63/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - accuracy: 0.7796 - loss: 1.4537 - val_accuracy: 0.5865 - val_loss: 1.6441 - learning_rate: 5.0000e-04
# Epoch 64/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.7541 - loss: 1.3791 - val_accuracy: 0.5657 - val_loss: 1.7884 - learning_rate: 5.0000e-04
# Epoch 65/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.6989 - loss: 1.6205 - val_accuracy: 0.5836 - val_loss: 1.6819 - learning_rate: 5.0000e-04
# Epoch 66/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7658 - loss: 1.4185 - val_accuracy: 0.5300 - val_loss: 1.8735 - learning_rate: 5.0000e-04
# Epoch 67/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.7678 - loss: 1.4666 - val_accuracy: 0.5750 - val_loss: 1.6692 - learning_rate: 5.0000e-04
# Epoch 68/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7369 - loss: 1.5744 - val_accuracy: 0.5525 - val_loss: 1.7640 - learning_rate: 5.0000e-04
# Epoch 69/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7657 - loss: 1.3369 - val_accuracy: 0.5784 - val_loss: 1.6610 - learning_rate: 5.0000e-04
# Epoch 70/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.7624 - loss: 1.3755 - val_accuracy: 0.5663 - val_loss: 1.7155 - learning_rate: 5.0000e-04
# Epoch 71/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.7732 - loss: 1.3863 - val_accuracy: 0.5900 - val_loss: 1.6642 - learning_rate: 5.0000e-04
# Epoch 72/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7799 - loss: 1.4025 - val_accuracy: 0.5600 - val_loss: 1.7986 - learning_rate: 5.0000e-04
# Epoch 73/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7910 - loss: 1.3002
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.7910 - loss: 1.3003 - val_accuracy: 0.5998 - val_loss: 1.6006 - learning_rate: 5.0000e-04
# Epoch 74/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7960 - loss: 1.3788 - val_accuracy: 0.6546 - val_loss: 1.4626 - learning_rate: 2.5000e-04
# Epoch 75/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7978 - loss: 1.3974 - val_accuracy: 0.6782 - val_loss: 1.3981 - learning_rate: 2.5000e-04
# Epoch 76/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.7783 - loss: 1.3821 - val_accuracy: 0.6355 - val_loss: 1.4889 - learning_rate: 2.5000e-04
# Epoch 77/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.8206 - loss: 1.2984 - val_accuracy: 0.6632 - val_loss: 1.3956 - learning_rate: 2.5000e-04
# Epoch 78/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8572 - loss: 1.2044 - val_accuracy: 0.6286 - val_loss: 1.5272 - learning_rate: 2.5000e-04
# Epoch 79/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8388 - loss: 1.2573 - val_accuracy: 0.6286 - val_loss: 1.5249 - learning_rate: 2.5000e-04
# Epoch 80/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8204 - loss: 1.2893 - val_accuracy: 0.6574 - val_loss: 1.4239 - learning_rate: 2.5000e-04
# Epoch 81/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.8106 - loss: 1.3490 - val_accuracy: 0.6580 - val_loss: 1.4156 - learning_rate: 2.5000e-04
# Epoch 82/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8240 - loss: 1.2320 - val_accuracy: 0.5877 - val_loss: 1.7088 - learning_rate: 2.5000e-04
# Epoch 83/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8155 - loss: 1.3132 - val_accuracy: 0.6101 - val_loss: 1.5662 - learning_rate: 2.5000e-04
# Epoch 84/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8339 - loss: 1.2048 - val_accuracy: 0.6257 - val_loss: 1.5003 - learning_rate: 2.5000e-04
# Epoch 85/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8198 - loss: 1.2197 - val_accuracy: 0.5888 - val_loss: 1.6410 - learning_rate: 2.5000e-04
# Epoch 86/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.8212 - loss: 1.2943 - val_accuracy: 0.6471 - val_loss: 1.4261 - learning_rate: 2.5000e-04
# Epoch 87/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.8472 - loss: 1.1056 - val_accuracy: 0.6522 - val_loss: 1.4282 - learning_rate: 2.5000e-04
# Epoch 88/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.8647 - loss: 1.1420 - val_accuracy: 0.5536 - val_loss: 1.7770 - learning_rate: 2.5000e-04
# Epoch 89/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8603 - loss: 1.1476 - val_accuracy: 0.5784 - val_loss: 1.6951 - learning_rate: 2.5000e-04
# Epoch 90/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8406 - loss: 1.2634 - val_accuracy: 0.6113 - val_loss: 1.5618 - learning_rate: 2.5000e-04
# Epoch 91/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8624 - loss: 1.1070 - val_accuracy: 0.6269 - val_loss: 1.5314 - learning_rate: 2.5000e-04
# Epoch 92/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.8738 - loss: 1.0856 - val_accuracy: 0.5882 - val_loss: 1.6275 - learning_rate: 2.5000e-04
# Epoch 93/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.8274 - loss: 1.2893 - val_accuracy: 0.6557 - val_loss: 1.4207 - learning_rate: 2.5000e-04
# Epoch 94/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.8334 - loss: 1.2454 - val_accuracy: 0.6275 - val_loss: 1.5042 - learning_rate: 2.5000e-04
# Epoch 95/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8762 - loss: 1.2096
# Epoch 95: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8760 - loss: 1.2096 - val_accuracy: 0.6188 - val_loss: 1.5630 - learning_rate: 2.5000e-04
# Epoch 96/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.8508 - loss: 1.2682 - val_accuracy: 0.6303 - val_loss: 1.4904 - learning_rate: 1.2500e-04
# Epoch 97/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8657 - loss: 1.1487 - val_accuracy: 0.6632 - val_loss: 1.4069 - learning_rate: 1.2500e-04
# Epoch 98/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9131 - loss: 1.0253 - val_accuracy: 0.6505 - val_loss: 1.4449 - learning_rate: 1.2500e-04
# Epoch 99/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8707 - loss: 1.1710 - val_accuracy: 0.6442 - val_loss: 1.4410 - learning_rate: 1.2500e-04
# Epoch 100/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8861 - loss: 1.0161 - val_accuracy: 0.6603 - val_loss: 1.3941 - learning_rate: 1.2500e-04
# Epoch 101/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8832 - loss: 1.1211 - val_accuracy: 0.6344 - val_loss: 1.5205 - learning_rate: 1.2500e-04
# Epoch 102/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8538 - loss: 1.2451 - val_accuracy: 0.6367 - val_loss: 1.4623 - learning_rate: 1.2500e-04
# Epoch 103/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8734 - loss: 1.1432 - val_accuracy: 0.6251 - val_loss: 1.5025 - learning_rate: 1.2500e-04
# Epoch 104/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8853 - loss: 1.0992 - val_accuracy: 0.6569 - val_loss: 1.4034 - learning_rate: 1.2500e-04
# Epoch 105/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8604 - loss: 1.2468 - val_accuracy: 0.6338 - val_loss: 1.4594 - learning_rate: 1.2500e-04
# Epoch 106/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.8767 - loss: 1.1097 - val_accuracy: 0.6511 - val_loss: 1.4413 - learning_rate: 1.2500e-04
# Epoch 107/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8836 - loss: 1.0021 - val_accuracy: 0.6522 - val_loss: 1.4485 - learning_rate: 1.2500e-04
# Epoch 108/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8962 - loss: 1.0381 - val_accuracy: 0.6528 - val_loss: 1.4532 - learning_rate: 1.2500e-04
# Epoch 109/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9078 - loss: 1.0755 - val_accuracy: 0.6534 - val_loss: 1.4228 - learning_rate: 1.2500e-04
# Epoch 110/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8783 - loss: 1.1132 - val_accuracy: 0.6367 - val_loss: 1.4957 - learning_rate: 1.2500e-04
# Epoch 111/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9028 - loss: 1.0782 - val_accuracy: 0.6171 - val_loss: 1.5359 - learning_rate: 1.2500e-04
# Epoch 112/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9009 - loss: 0.9872 - val_accuracy: 0.6649 - val_loss: 1.3958 - learning_rate: 1.2500e-04
# Epoch 113/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9224 - loss: 0.9202 - val_accuracy: 0.6205 - val_loss: 1.5652 - learning_rate: 1.2500e-04
# Epoch 114/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8969 - loss: 1.0517 - val_accuracy: 0.6505 - val_loss: 1.4280 - learning_rate: 1.2500e-04
# Epoch 115/160
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8755 - loss: 1.0935
# Epoch 115: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.8757 - loss: 1.0930 - val_accuracy: 0.6430 - val_loss: 1.4108 - learning_rate: 1.2500e-04
# Epoch 115: early stopping
# Restoring model weights from the end of the best epoch: 75.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# Fold 5 - Accuracy: 0.6782, F1-macro: 0.7078
#
# === All 18 Gestures CV Results ===
# CV Accuracy: 0.6677 ± 0.0290
# CV F1-macro: 0.7043 ± 0.0309
#
# === All 18 Gestures Classification Report ===
#                                             precision    recall  f1-score   support
#
#                      Above ear - pull hair     0.5901    0.6160    0.6028       638
#                         Cheek - pinch skin     0.4932    0.4521    0.4717       637
#                      Drink from bottle/cup     0.9864    0.9006    0.9416       161
#                        Eyebrow - pull hair     0.4300    0.3417    0.3808       638
#                        Eyelash - pull hair     0.4749    0.5469    0.5084       640
# Feel around in tray and pull out an object     0.9493    0.8137    0.8763       161
#                   Forehead - pull hairline     0.6833    0.5766    0.6254       640
#                         Forehead - scratch     0.7075    0.7406    0.7237       640
#                             Glasses on/off     0.9080    0.9193    0.9136       161
#                          Neck - pinch skin     0.5156    0.5672    0.5402       640
#                             Neck - scratch     0.5613    0.5797    0.5703       640
#                        Pinch knee/leg skin     0.6835    0.6708    0.6771       161
#                  Pull air toward your face     0.9513    0.9413    0.9463       477
#                      Scratch knee/leg skin     0.5544    0.6646    0.6045       161
#                              Text on phone     0.8393    0.9141    0.8751       640
#                                 Wave hello     0.8367    0.8787    0.8571       478
#                          Write name in air     0.8771    0.8679    0.8725       477
#                          Write name on leg     0.7500    0.6522    0.6977       161
#
#                                   accuracy                         0.6672      8151
#                                  macro avg     0.7107    0.7024    0.7047      8151
#                               weighted avg     0.6668    0.6672    0.6653      8151

# %%
print("\n" + "="*60)
print("EXPERIMENT 2: BFRB 8 Gestures Specialized Classification") 
print("="*60)

# Filter data for BFRB gestures only
bfrb_mask = train['gesture'].isin(config.bfrb_gestures)
train_bfrb = train[bfrb_mask].copy()

# Re-encode labels for BFRB only (0-7)
le_bfrb = LabelEncoder()
train_bfrb["e_gesture_bfrb"] = le_bfrb.fit_transform(train_bfrb["gesture"])
bfrb_gesture_classes = le_bfrb.classes_

print(f"BFRB data: {len(train_bfrb)} rows, {train_bfrb['sequence_id'].nunique()} sequences")
print(f"BFRB classes: {list(bfrb_gesture_classes)}")

# Prepare sequences for BFRB only
X_bfrb, y_bfrb, seq_ids_bfrb, imu_dim_bfrb, extra_dim_bfrb = prepare_sequences_for_dl(train_bfrb, config, label_column="e_gesture_bfrb")
subjects_bfrb = np.array([subject_mapping[seq_id] for seq_id in seq_ids_bfrb])

# Train BFRB specialized model
results_bfrb = train_deep_learning_cv(
    X_bfrb, y_bfrb, seq_ids_bfrb, subjects_bfrb, bfrb_gesture_classes,
    imu_dim_bfrb, extra_dim_bfrb, config, "BFRB 8 Gestures Specialized"
)
# Out:
# ============================================================
# EXPERIMENT 2: BFRB 8 Gestures Specialized Classification
# ============================================================
# BFRB data: 344058 rows, 5113 sequences
# BFRB classes: ['Above ear - pull hair', 'Cheek - pinch skin', 'Eyebrow - pull hair', 'Eyelash - pull hair', 'Forehead - pull hairline', 'Forehead - scratch', 'Neck - pinch skin', 'Neck - scratch']
# Creating features...
# Building sequences...
# Processing sequences: 100%|██████████| 5113/5113 [00:43<00:00, 117.27it/s]
# === BFRB 8 Gestures Specialized Deep Learning CV ===
# Total sequences: 5113
# Classes: 8
# IMU features: 17, Extra features: 25
# Padding length: 110
#
# Fold 1/5
# Train: 4089, Val: 1024
# Epoch 1/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - accuracy: 0.1562 - loss: 9.2998 - val_accuracy: 0.1875 - val_loss: 8.1394 - learning_rate: 5.0000e-04
# Epoch 2/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.2325 - loss: 8.0027 - val_accuracy: 0.2305 - val_loss: 7.2224 - learning_rate: 5.0000e-04
# Epoch 3/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.2593 - loss: 7.1006 - val_accuracy: 0.3047 - val_loss: 6.4243 - learning_rate: 5.0000e-04
# Epoch 4/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.2941 - loss: 6.3589 - val_accuracy: 0.3232 - val_loss: 5.8049 - learning_rate: 5.0000e-04
# Epoch 5/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.3251 - loss: 5.7594 - val_accuracy: 0.3574 - val_loss: 5.2828 - learning_rate: 5.0000e-04
# Epoch 6/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.3561 - loss: 5.2540 - val_accuracy: 0.3838 - val_loss: 4.8538 - learning_rate: 5.0000e-04
# Epoch 7/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.4027 - loss: 4.7922 - val_accuracy: 0.3428 - val_loss: 4.5726 - learning_rate: 5.0000e-04
# Epoch 8/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.3808 - loss: 4.5285 - val_accuracy: 0.3779 - val_loss: 4.2233 - learning_rate: 5.0000e-04
# Epoch 9/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.4350 - loss: 4.1122 - val_accuracy: 0.3359 - val_loss: 4.0906 - learning_rate: 5.0000e-04
# Epoch 10/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.4434 - loss: 3.9016 - val_accuracy: 0.3877 - val_loss: 3.7501 - learning_rate: 5.0000e-04
# Epoch 11/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.4580 - loss: 3.6765 - val_accuracy: 0.4170 - val_loss: 3.5160 - learning_rate: 5.0000e-04
# Epoch 12/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.4645 - loss: 3.4794 - val_accuracy: 0.3799 - val_loss: 3.4431 - learning_rate: 5.0000e-04
# Epoch 13/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.4955 - loss: 3.2605 - val_accuracy: 0.3652 - val_loss: 3.3909 - learning_rate: 5.0000e-04
# Epoch 14/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.5154 - loss: 3.0954 - val_accuracy: 0.3477 - val_loss: 3.2296 - learning_rate: 5.0000e-04
# Epoch 15/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.5099 - loss: 3.0404 - val_accuracy: 0.3926 - val_loss: 2.9997 - learning_rate: 5.0000e-04
# Epoch 16/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.5284 - loss: 2.8183 - val_accuracy: 0.4521 - val_loss: 2.7671 - learning_rate: 5.0000e-04
# Epoch 17/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.4995 - loss: 2.7647 - val_accuracy: 0.4453 - val_loss: 2.7487 - learning_rate: 5.0000e-04
# Epoch 18/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.5467 - loss: 2.5911 - val_accuracy: 0.4160 - val_loss: 2.6645 - learning_rate: 5.0000e-04
# Epoch 19/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.5514 - loss: 2.5093 - val_accuracy: 0.4287 - val_loss: 2.5458 - learning_rate: 5.0000e-04
# Epoch 20/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.5541 - loss: 2.3741 - val_accuracy: 0.4082 - val_loss: 2.5340 - learning_rate: 5.0000e-04
# Epoch 21/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.5709 - loss: 2.3515 - val_accuracy: 0.3271 - val_loss: 2.7349 - learning_rate: 5.0000e-04
# Epoch 22/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.5893 - loss: 2.2687 - val_accuracy: 0.3574 - val_loss: 2.6420 - learning_rate: 5.0000e-04
# Epoch 23/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.5840 - loss: 2.2094 - val_accuracy: 0.4531 - val_loss: 2.3364 - learning_rate: 5.0000e-04
# Epoch 24/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.5858 - loss: 2.1638 - val_accuracy: 0.4736 - val_loss: 2.2550 - learning_rate: 5.0000e-04
# Epoch 25/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.6089 - loss: 2.0940 - val_accuracy: 0.4473 - val_loss: 2.2823 - learning_rate: 5.0000e-04
# Epoch 26/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.6264 - loss: 2.0053 - val_accuracy: 0.4307 - val_loss: 2.2814 - learning_rate: 5.0000e-04
# Epoch 27/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.6321 - loss: 1.9362 - val_accuracy: 0.4072 - val_loss: 2.4427 - learning_rate: 5.0000e-04
# Epoch 28/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.6679 - loss: 1.8130 - val_accuracy: 0.4248 - val_loss: 2.1884 - learning_rate: 5.0000e-04
# Epoch 29/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.6692 - loss: 1.8442 - val_accuracy: 0.4814 - val_loss: 2.0950 - learning_rate: 5.0000e-04
# Epoch 30/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.6286 - loss: 1.8174 - val_accuracy: 0.3662 - val_loss: 2.4714 - learning_rate: 5.0000e-04
# Epoch 31/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7042 - loss: 1.6998 - val_accuracy: 0.4404 - val_loss: 2.1397 - learning_rate: 5.0000e-04
# Epoch 32/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.6707 - loss: 1.7030 - val_accuracy: 0.4541 - val_loss: 2.1599 - learning_rate: 5.0000e-04
# Epoch 33/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.6860 - loss: 1.7239 - val_accuracy: 0.3613 - val_loss: 2.3528 - learning_rate: 5.0000e-04
# Epoch 34/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.7106 - loss: 1.6654 - val_accuracy: 0.4473 - val_loss: 2.0619 - learning_rate: 5.0000e-04
# Epoch 35/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.7164 - loss: 1.6053 - val_accuracy: 0.4326 - val_loss: 2.0881 - learning_rate: 5.0000e-04
# Epoch 36/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.7232 - loss: 1.5399 - val_accuracy: 0.2871 - val_loss: 2.7378 - learning_rate: 5.0000e-04
# Epoch 37/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7309 - loss: 1.4998 - val_accuracy: 0.2334 - val_loss: 3.1561 - learning_rate: 5.0000e-04
# Epoch 38/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.6678 - loss: 1.6995 - val_accuracy: 0.4248 - val_loss: 2.1001 - learning_rate: 5.0000e-04
# Epoch 39/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.7413 - loss: 1.4304 - val_accuracy: 0.3691 - val_loss: 2.5017 - learning_rate: 5.0000e-04
# Epoch 40/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.7518 - loss: 1.4545 - val_accuracy: 0.4111 - val_loss: 2.2876 - learning_rate: 5.0000e-04
# Epoch 41/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.7362 - loss: 1.5206 - val_accuracy: 0.4131 - val_loss: 2.1634 - learning_rate: 5.0000e-04
# Epoch 42/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7135 - loss: 1.5600 - val_accuracy: 0.4580 - val_loss: 1.9816 - learning_rate: 5.0000e-04
# Epoch 43/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.7793 - loss: 1.3589 - val_accuracy: 0.4395 - val_loss: 2.0134 - learning_rate: 5.0000e-04
# Epoch 44/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7620 - loss: 1.5023 - val_accuracy: 0.3301 - val_loss: 2.5943 - learning_rate: 5.0000e-04
# Epoch 45/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7314 - loss: 1.5440 - val_accuracy: 0.4277 - val_loss: 2.0971 - learning_rate: 5.0000e-04
# Epoch 46/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7881 - loss: 1.3414 - val_accuracy: 0.4736 - val_loss: 1.9511 - learning_rate: 5.0000e-04
# Epoch 47/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7956 - loss: 1.3768 - val_accuracy: 0.4258 - val_loss: 2.0793 - learning_rate: 5.0000e-04
# Epoch 48/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7739 - loss: 1.4452 - val_accuracy: 0.4082 - val_loss: 2.1186 - learning_rate: 5.0000e-04
# Epoch 49/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7766 - loss: 1.4253
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7764 - loss: 1.4258 - val_accuracy: 0.4111 - val_loss: 2.0847 - learning_rate: 5.0000e-04
# Epoch 50/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7923 - loss: 1.3955 - val_accuracy: 0.4609 - val_loss: 1.9797 - learning_rate: 2.5000e-04
# Epoch 51/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7728 - loss: 1.3978 - val_accuracy: 0.4570 - val_loss: 2.0335 - learning_rate: 2.5000e-04
# Epoch 52/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8367 - loss: 1.2447 - val_accuracy: 0.4668 - val_loss: 2.0402 - learning_rate: 2.5000e-04
# Epoch 53/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8407 - loss: 1.2899 - val_accuracy: 0.4727 - val_loss: 1.9365 - learning_rate: 2.5000e-04
# Epoch 54/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8241 - loss: 1.2876 - val_accuracy: 0.4805 - val_loss: 1.9164 - learning_rate: 2.5000e-04
# Epoch 55/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8542 - loss: 1.1914 - val_accuracy: 0.4844 - val_loss: 1.9115 - learning_rate: 2.5000e-04
# Epoch 56/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8464 - loss: 1.2037 - val_accuracy: 0.5029 - val_loss: 1.8916 - learning_rate: 2.5000e-04
# Epoch 57/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8523 - loss: 1.2077 - val_accuracy: 0.4795 - val_loss: 1.9307 - learning_rate: 2.5000e-04
# Epoch 58/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8322 - loss: 1.3442 - val_accuracy: 0.4414 - val_loss: 2.0399 - learning_rate: 2.5000e-04
# Epoch 59/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8850 - loss: 1.0813 - val_accuracy: 0.3916 - val_loss: 2.2807 - learning_rate: 2.5000e-04
# Epoch 60/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8585 - loss: 1.1563 - val_accuracy: 0.4541 - val_loss: 2.0076 - learning_rate: 2.5000e-04
# Epoch 61/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8972 - loss: 1.0897 - val_accuracy: 0.4512 - val_loss: 1.9980 - learning_rate: 2.5000e-04
# Epoch 62/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8488 - loss: 1.2390 - val_accuracy: 0.3799 - val_loss: 2.3354 - learning_rate: 2.5000e-04
# Epoch 63/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8766 - loss: 1.1596 - val_accuracy: 0.4814 - val_loss: 1.9184 - learning_rate: 2.5000e-04
# Epoch 64/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8941 - loss: 1.0243 - val_accuracy: 0.4551 - val_loss: 1.9537 - learning_rate: 2.5000e-04
# Epoch 65/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8668 - loss: 1.1152 - val_accuracy: 0.4346 - val_loss: 2.0739 - learning_rate: 2.5000e-04
# Epoch 66/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9009 - loss: 0.9698 - val_accuracy: 0.4082 - val_loss: 2.2502 - learning_rate: 2.5000e-04
# Epoch 67/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.8795 - loss: 1.1009 - val_accuracy: 0.4590 - val_loss: 2.0598 - learning_rate: 2.5000e-04
# Epoch 68/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8514 - loss: 1.2200 - val_accuracy: 0.3672 - val_loss: 2.2918 - learning_rate: 2.5000e-04
# Epoch 69/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9148 - loss: 1.0242 - val_accuracy: 0.4736 - val_loss: 1.9532 - learning_rate: 2.5000e-04
# Epoch 70/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8771 - loss: 1.1329 - val_accuracy: 0.4365 - val_loss: 1.9664 - learning_rate: 2.5000e-04
# Epoch 71/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8716 - loss: 1.1044 - val_accuracy: 0.4590 - val_loss: 1.9887 - learning_rate: 2.5000e-04
# Epoch 72/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8808 - loss: 1.1222 - val_accuracy: 0.4736 - val_loss: 1.9619 - learning_rate: 2.5000e-04
# Epoch 73/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8482 - loss: 1.1225 - val_accuracy: 0.4785 - val_loss: 1.9266 - learning_rate: 2.5000e-04
# Epoch 74/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8736 - loss: 1.1142 - val_accuracy: 0.4629 - val_loss: 1.9042 - learning_rate: 2.5000e-04
# Epoch 75/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9224 - loss: 1.0294 - val_accuracy: 0.4199 - val_loss: 2.0742 - learning_rate: 2.5000e-04
# Epoch 76/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8835 - loss: 1.1195
# Epoch 76: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8832 - loss: 1.1201 - val_accuracy: 0.3887 - val_loss: 2.1768 - learning_rate: 2.5000e-04
# Epoch 77/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9115 - loss: 0.9952 - val_accuracy: 0.5088 - val_loss: 1.8206 - learning_rate: 1.2500e-04
# Epoch 78/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9019 - loss: 1.0645 - val_accuracy: 0.4785 - val_loss: 1.9298 - learning_rate: 1.2500e-04
# Epoch 79/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9117 - loss: 1.1495 - val_accuracy: 0.4932 - val_loss: 1.8610 - learning_rate: 1.2500e-04
# Epoch 80/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9295 - loss: 1.0620 - val_accuracy: 0.4668 - val_loss: 1.9437 - learning_rate: 1.2500e-04
# Epoch 81/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9182 - loss: 0.8928 - val_accuracy: 0.5000 - val_loss: 1.8373 - learning_rate: 1.2500e-04
# Epoch 82/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8916 - loss: 1.0373 - val_accuracy: 0.4893 - val_loss: 1.8592 - learning_rate: 1.2500e-04
# Epoch 83/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9145 - loss: 0.9739 - val_accuracy: 0.4248 - val_loss: 2.1582 - learning_rate: 1.2500e-04
# Epoch 84/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9432 - loss: 0.8080 - val_accuracy: 0.4766 - val_loss: 1.9529 - learning_rate: 1.2500e-04
# Epoch 85/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9257 - loss: 0.9858 - val_accuracy: 0.4902 - val_loss: 1.8810 - learning_rate: 1.2500e-04
# Epoch 86/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8682 - loss: 1.1014 - val_accuracy: 0.4922 - val_loss: 1.8548 - learning_rate: 1.2500e-04
# Epoch 87/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8512 - loss: 1.1779 - val_accuracy: 0.4932 - val_loss: 1.8143 - learning_rate: 1.2500e-04
# Epoch 88/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9045 - loss: 0.9595 - val_accuracy: 0.4707 - val_loss: 1.9895 - learning_rate: 1.2500e-04
# Epoch 89/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9389 - loss: 1.0569 - val_accuracy: 0.4648 - val_loss: 1.9838 - learning_rate: 1.2500e-04
# Epoch 90/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9678 - loss: 0.8000 - val_accuracy: 0.4912 - val_loss: 1.8955 - learning_rate: 1.2500e-04
# Epoch 91/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9165 - loss: 0.9299 - val_accuracy: 0.4707 - val_loss: 1.9037 - learning_rate: 1.2500e-04
# Epoch 92/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9623 - loss: 0.8302 - val_accuracy: 0.4834 - val_loss: 1.9056 - learning_rate: 1.2500e-04
# Epoch 93/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9135 - loss: 1.0344 - val_accuracy: 0.4873 - val_loss: 1.8610 - learning_rate: 1.2500e-04
# Epoch 94/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9260 - loss: 0.9695 - val_accuracy: 0.4766 - val_loss: 1.8627 - learning_rate: 1.2500e-04
# Epoch 95/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9448 - loss: 0.8706 - val_accuracy: 0.4961 - val_loss: 1.9088 - learning_rate: 1.2500e-04
# Epoch 96/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9054 - loss: 0.9999 - val_accuracy: 0.4990 - val_loss: 1.8475 - learning_rate: 1.2500e-04
# Epoch 97/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9351 - loss: 0.9105
# Epoch 97: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9347 - loss: 0.9123 - val_accuracy: 0.3867 - val_loss: 2.2230 - learning_rate: 1.2500e-04
# Epoch 98/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9381 - loss: 0.8685 - val_accuracy: 0.5146 - val_loss: 1.8077 - learning_rate: 6.2500e-05
# Epoch 99/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9378 - loss: 0.9091 - val_accuracy: 0.5000 - val_loss: 1.8247 - learning_rate: 6.2500e-05
# Epoch 100/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9452 - loss: 0.8965 - val_accuracy: 0.5127 - val_loss: 1.8165 - learning_rate: 6.2500e-05
# Epoch 101/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9255 - loss: 0.9680 - val_accuracy: 0.5088 - val_loss: 1.8268 - learning_rate: 6.2500e-05
# Epoch 102/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9142 - loss: 0.9715 - val_accuracy: 0.5049 - val_loss: 1.7845 - learning_rate: 6.2500e-05
# Epoch 103/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9568 - loss: 0.8921 - val_accuracy: 0.5312 - val_loss: 1.7470 - learning_rate: 6.2500e-05
# Epoch 104/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9283 - loss: 1.0389 - val_accuracy: 0.4941 - val_loss: 1.8334 - learning_rate: 6.2500e-05
# Epoch 105/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9269 - loss: 0.8926 - val_accuracy: 0.5215 - val_loss: 1.7778 - learning_rate: 6.2500e-05
# Epoch 106/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9229 - loss: 0.8794 - val_accuracy: 0.5078 - val_loss: 1.8066 - learning_rate: 6.2500e-05
# Epoch 107/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9502 - loss: 0.8823 - val_accuracy: 0.5098 - val_loss: 1.8399 - learning_rate: 6.2500e-05
# Epoch 108/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9437 - loss: 0.9278 - val_accuracy: 0.4941 - val_loss: 1.8125 - learning_rate: 6.2500e-05
# Epoch 109/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9135 - loss: 0.9920 - val_accuracy: 0.5283 - val_loss: 1.8159 - learning_rate: 6.2500e-05
# Epoch 110/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9788 - loss: 0.7230 - val_accuracy: 0.4932 - val_loss: 1.8388 - learning_rate: 6.2500e-05
# Epoch 111/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9435 - loss: 0.9140 - val_accuracy: 0.4951 - val_loss: 1.7984 - learning_rate: 6.2500e-05
# Epoch 112/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9462 - loss: 0.8410 - val_accuracy: 0.4775 - val_loss: 1.8827 - learning_rate: 6.2500e-05
# Epoch 113/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9579 - loss: 0.8232 - val_accuracy: 0.5176 - val_loss: 1.8286 - learning_rate: 6.2500e-05
# Epoch 114/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9401 - loss: 0.9299 - val_accuracy: 0.4990 - val_loss: 1.8233 - learning_rate: 6.2500e-05
# Epoch 115/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9299 - loss: 0.9791 - val_accuracy: 0.4932 - val_loss: 1.8413 - learning_rate: 6.2500e-05
# Epoch 116/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9362 - loss: 0.9449 - val_accuracy: 0.4873 - val_loss: 1.8451 - learning_rate: 6.2500e-05
# Epoch 117/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9371 - loss: 0.8772 - val_accuracy: 0.5059 - val_loss: 1.8078 - learning_rate: 6.2500e-05
# Epoch 118/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9249 - loss: 0.9297 - val_accuracy: 0.4697 - val_loss: 1.9544 - learning_rate: 6.2500e-05
# Epoch 119/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9450 - loss: 0.9157 - val_accuracy: 0.4785 - val_loss: 1.8803 - learning_rate: 6.2500e-05
# Epoch 120/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9180 - loss: 0.8978 - val_accuracy: 0.5020 - val_loss: 1.8326 - learning_rate: 6.2500e-05
# Epoch 121/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9452 - loss: 0.8790 - val_accuracy: 0.4971 - val_loss: 1.7839 - learning_rate: 6.2500e-05
# Epoch 122/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9335 - loss: 0.8181 - val_accuracy: 0.4961 - val_loss: 1.8258 - learning_rate: 6.2500e-05
# Epoch 123/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9453 - loss: 0.8964
# Epoch 123: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9454 - loss: 0.8954 - val_accuracy: 0.5127 - val_loss: 1.7786 - learning_rate: 6.2500e-05
# Epoch 124/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9581 - loss: 0.7614 - val_accuracy: 0.5000 - val_loss: 1.8359 - learning_rate: 3.1250e-05
# Epoch 125/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9345 - loss: 0.8018 - val_accuracy: 0.5156 - val_loss: 1.7688 - learning_rate: 3.1250e-05
# Epoch 126/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9097 - loss: 1.0646 - val_accuracy: 0.5078 - val_loss: 1.7821 - learning_rate: 3.1250e-05
# Epoch 127/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9442 - loss: 0.9596 - val_accuracy: 0.5059 - val_loss: 1.7594 - learning_rate: 3.1250e-05
# Epoch 128/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9006 - loss: 0.9445 - val_accuracy: 0.5156 - val_loss: 1.7790 - learning_rate: 3.1250e-05
# Epoch 129/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9256 - loss: 0.8892 - val_accuracy: 0.5078 - val_loss: 1.8080 - learning_rate: 3.1250e-05
# Epoch 130/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9502 - loss: 0.8014 - val_accuracy: 0.5225 - val_loss: 1.7881 - learning_rate: 3.1250e-05
# Epoch 131/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9267 - loss: 0.9561 - val_accuracy: 0.4961 - val_loss: 1.8080 - learning_rate: 3.1250e-05
# Epoch 132/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9284 - loss: 0.9475 - val_accuracy: 0.5098 - val_loss: 1.8150 - learning_rate: 3.1250e-05
# Epoch 133/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9485 - loss: 0.8756 - val_accuracy: 0.4961 - val_loss: 1.8575 - learning_rate: 3.1250e-05
# Epoch 134/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9472 - loss: 0.8569 - val_accuracy: 0.5088 - val_loss: 1.7462 - learning_rate: 3.1250e-05
# Epoch 135/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8944 - loss: 1.0479 - val_accuracy: 0.4863 - val_loss: 1.8332 - learning_rate: 3.1250e-05
# Epoch 136/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9680 - loss: 0.8334 - val_accuracy: 0.5107 - val_loss: 1.7697 - learning_rate: 3.1250e-05
# Epoch 137/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9591 - loss: 0.7569 - val_accuracy: 0.5137 - val_loss: 1.8111 - learning_rate: 3.1250e-05
# Epoch 138/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9337 - loss: 0.8593 - val_accuracy: 0.5000 - val_loss: 1.7996 - learning_rate: 3.1250e-05
# Epoch 139/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9094 - loss: 0.8780 - val_accuracy: 0.5039 - val_loss: 1.8149 - learning_rate: 3.1250e-05
# Epoch 140/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9583 - loss: 0.7728 - val_accuracy: 0.5068 - val_loss: 1.7941 - learning_rate: 3.1250e-05
# Epoch 141/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9102 - loss: 1.0065 - val_accuracy: 0.5127 - val_loss: 1.7857 - learning_rate: 3.1250e-05
# Epoch 142/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9297 - loss: 0.9609 - val_accuracy: 0.5107 - val_loss: 1.7908 - learning_rate: 3.1250e-05
# Epoch 143/160
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9476 - loss: 0.8680
# Epoch 143: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9475 - loss: 0.8673 - val_accuracy: 0.5166 - val_loss: 1.7950 - learning_rate: 3.1250e-05
# Epoch 143: early stopping
# Restoring model weights from the end of the best epoch: 103.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Fold 1 - Accuracy: 0.5312, F1-macro: 0.5273
#
# Fold 2/5
# Train: 4031, Val: 1082
# Epoch 1/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.1555 - loss: 9.2291 - val_accuracy: 0.1433 - val_loss: 8.1959 - learning_rate: 5.0000e-04
# Epoch 2/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.2250 - loss: 8.0387 - val_accuracy: 0.2560 - val_loss: 7.2969 - learning_rate: 5.0000e-04
# Epoch 3/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.2435 - loss: 7.2214 - val_accuracy: 0.3262 - val_loss: 6.5037 - learning_rate: 5.0000e-04
# Epoch 4/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.2912 - loss: 6.4570 - val_accuracy: 0.3549 - val_loss: 5.8584 - learning_rate: 5.0000e-04
# Epoch 5/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.3147 - loss: 5.8631 - val_accuracy: 0.3725 - val_loss: 5.3576 - learning_rate: 5.0000e-04
# Epoch 6/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.3316 - loss: 5.3922 - val_accuracy: 0.4427 - val_loss: 4.8362 - learning_rate: 5.0000e-04
# Epoch 7/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.3489 - loss: 4.9534 - val_accuracy: 0.3595 - val_loss: 4.6275 - learning_rate: 5.0000e-04
# Epoch 8/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.3694 - loss: 4.6217 - val_accuracy: 0.4372 - val_loss: 4.1684 - learning_rate: 5.0000e-04
# Epoch 9/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.4029 - loss: 4.2732 - val_accuracy: 0.4723 - val_loss: 3.8936 - learning_rate: 5.0000e-04
# Epoch 10/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.4257 - loss: 3.9691 - val_accuracy: 0.4122 - val_loss: 3.8678 - learning_rate: 5.0000e-04
# Epoch 11/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.4622 - loss: 3.7630 - val_accuracy: 0.4122 - val_loss: 3.6228 - learning_rate: 5.0000e-04
# Epoch 12/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.4687 - loss: 3.5269 - val_accuracy: 0.4538 - val_loss: 3.3104 - learning_rate: 5.0000e-04
# Epoch 13/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.4992 - loss: 3.3049 - val_accuracy: 0.4455 - val_loss: 3.2015 - learning_rate: 5.0000e-04
# Epoch 14/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.4934 - loss: 3.1637 - val_accuracy: 0.4741 - val_loss: 2.9778 - learning_rate: 5.0000e-04
# Epoch 15/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.5072 - loss: 3.0634 - val_accuracy: 0.4769 - val_loss: 2.8801 - learning_rate: 5.0000e-04
# Epoch 16/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.5347 - loss: 2.8963 - val_accuracy: 0.4677 - val_loss: 2.7858 - learning_rate: 5.0000e-04
# Epoch 17/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.5003 - loss: 2.8271 - val_accuracy: 0.4713 - val_loss: 2.6940 - learning_rate: 5.0000e-04
# Epoch 18/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.5639 - loss: 2.6235 - val_accuracy: 0.5203 - val_loss: 2.5138 - learning_rate: 5.0000e-04
# Epoch 19/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5816 - loss: 2.5038 - val_accuracy: 0.4686 - val_loss: 2.5589 - learning_rate: 5.0000e-04
# Epoch 20/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.5806 - loss: 2.4462 - val_accuracy: 0.4593 - val_loss: 2.4831 - learning_rate: 5.0000e-04
# Epoch 21/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.5756 - loss: 2.3433 - val_accuracy: 0.4713 - val_loss: 2.3716 - learning_rate: 5.0000e-04
# Epoch 22/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5959 - loss: 2.2109 - val_accuracy: 0.4288 - val_loss: 2.4627 - learning_rate: 5.0000e-04
# Epoch 23/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.6203 - loss: 2.1299 - val_accuracy: 0.4603 - val_loss: 2.3019 - learning_rate: 5.0000e-04
# Epoch 24/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6284 - loss: 2.1461 - val_accuracy: 0.4704 - val_loss: 2.2570 - learning_rate: 5.0000e-04
# Epoch 25/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.6199 - loss: 2.0723 - val_accuracy: 0.4473 - val_loss: 2.3047 - learning_rate: 5.0000e-04
# Epoch 26/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.6408 - loss: 1.9530 - val_accuracy: 0.5074 - val_loss: 2.0848 - learning_rate: 5.0000e-04
# Epoch 27/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.6556 - loss: 1.9492 - val_accuracy: 0.3909 - val_loss: 2.3204 - learning_rate: 5.0000e-04
# Epoch 28/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.6551 - loss: 1.8665 - val_accuracy: 0.5277 - val_loss: 1.9924 - learning_rate: 5.0000e-04
# Epoch 29/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.6537 - loss: 1.9751 - val_accuracy: 0.4529 - val_loss: 2.2622 - learning_rate: 5.0000e-04
# Epoch 30/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.6905 - loss: 1.7334 - val_accuracy: 0.4335 - val_loss: 2.2158 - learning_rate: 5.0000e-04
# Epoch 31/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.6669 - loss: 1.7745 - val_accuracy: 0.4797 - val_loss: 2.0309 - learning_rate: 5.0000e-04
# Epoch 32/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.6917 - loss: 1.7856 - val_accuracy: 0.4658 - val_loss: 2.0895 - learning_rate: 5.0000e-04
# Epoch 33/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7027 - loss: 1.7035 - val_accuracy: 0.5360 - val_loss: 1.8705 - learning_rate: 5.0000e-04
# Epoch 34/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7051 - loss: 1.6890 - val_accuracy: 0.5120 - val_loss: 1.9177 - learning_rate: 5.0000e-04
# Epoch 35/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7313 - loss: 1.5735 - val_accuracy: 0.4039 - val_loss: 2.3011 - learning_rate: 5.0000e-04
# Epoch 36/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7152 - loss: 1.6939 - val_accuracy: 0.4455 - val_loss: 2.1467 - learning_rate: 5.0000e-04
# Epoch 37/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7020 - loss: 1.6441 - val_accuracy: 0.4880 - val_loss: 1.9380 - learning_rate: 5.0000e-04
# Epoch 38/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7371 - loss: 1.5455 - val_accuracy: 0.4288 - val_loss: 2.0402 - learning_rate: 5.0000e-04
# Epoch 39/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.7161 - loss: 1.5705 - val_accuracy: 0.4039 - val_loss: 2.3758 - learning_rate: 5.0000e-04
# Epoch 40/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7380 - loss: 1.6020 - val_accuracy: 0.4556 - val_loss: 2.1808 - learning_rate: 5.0000e-04
# Epoch 41/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7319 - loss: 1.5583 - val_accuracy: 0.4510 - val_loss: 2.1134 - learning_rate: 5.0000e-04
# Epoch 42/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7567 - loss: 1.4712 - val_accuracy: 0.4677 - val_loss: 2.1165 - learning_rate: 5.0000e-04
# Epoch 43/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6902 - loss: 1.6476 - val_accuracy: 0.5139 - val_loss: 1.7908 - learning_rate: 5.0000e-04
# Epoch 44/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7568 - loss: 1.5721 - val_accuracy: 0.5092 - val_loss: 1.8807 - learning_rate: 5.0000e-04
# Epoch 45/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7736 - loss: 1.3914 - val_accuracy: 0.4603 - val_loss: 1.9607 - learning_rate: 5.0000e-04
# Epoch 46/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.7627 - loss: 1.4562 - val_accuracy: 0.4815 - val_loss: 1.9231 - learning_rate: 5.0000e-04
# Epoch 47/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7617 - loss: 1.4918 - val_accuracy: 0.4177 - val_loss: 2.2330 - learning_rate: 5.0000e-04
# Epoch 48/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7907 - loss: 1.4055 - val_accuracy: 0.5074 - val_loss: 1.8887 - learning_rate: 5.0000e-04
# Epoch 49/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7817 - loss: 1.4957 - val_accuracy: 0.4787 - val_loss: 2.0019 - learning_rate: 5.0000e-04
# Epoch 50/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7639 - loss: 1.5184 - val_accuracy: 0.4723 - val_loss: 1.9585 - learning_rate: 5.0000e-04
# Epoch 51/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7899 - loss: 1.4386 - val_accuracy: 0.4787 - val_loss: 1.9493 - learning_rate: 5.0000e-04
# Epoch 52/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8237 - loss: 1.3379 - val_accuracy: 0.4880 - val_loss: 1.8894 - learning_rate: 5.0000e-04
# Epoch 53/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7915 - loss: 1.4524
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7912 - loss: 1.4527 - val_accuracy: 0.4473 - val_loss: 2.0006 - learning_rate: 5.0000e-04
# Epoch 54/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8153 - loss: 1.3225 - val_accuracy: 0.5231 - val_loss: 1.7907 - learning_rate: 2.5000e-04
# Epoch 55/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8877 - loss: 1.1565 - val_accuracy: 0.5009 - val_loss: 1.9172 - learning_rate: 2.5000e-04
# Epoch 56/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8557 - loss: 1.2786 - val_accuracy: 0.4945 - val_loss: 1.9182 - learning_rate: 2.5000e-04
# Epoch 57/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8893 - loss: 1.1087 - val_accuracy: 0.4963 - val_loss: 1.8595 - learning_rate: 2.5000e-04
# Epoch 58/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8969 - loss: 1.0933 - val_accuracy: 0.5259 - val_loss: 1.8329 - learning_rate: 2.5000e-04
# Epoch 59/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8997 - loss: 1.1104 - val_accuracy: 0.5499 - val_loss: 1.6998 - learning_rate: 2.5000e-04
# Epoch 60/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8604 - loss: 1.2612 - val_accuracy: 0.5055 - val_loss: 1.8503 - learning_rate: 2.5000e-04
# Epoch 61/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9108 - loss: 1.1063 - val_accuracy: 0.4880 - val_loss: 1.8696 - learning_rate: 2.5000e-04
# Epoch 62/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8840 - loss: 1.2378 - val_accuracy: 0.4529 - val_loss: 2.0479 - learning_rate: 2.5000e-04
# Epoch 63/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8780 - loss: 1.1498 - val_accuracy: 0.5379 - val_loss: 1.7708 - learning_rate: 2.5000e-04
# Epoch 64/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8403 - loss: 1.2459 - val_accuracy: 0.5240 - val_loss: 1.8064 - learning_rate: 2.5000e-04
# Epoch 65/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8897 - loss: 1.1376 - val_accuracy: 0.4196 - val_loss: 2.1848 - learning_rate: 2.5000e-04
# Epoch 66/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8789 - loss: 1.1391 - val_accuracy: 0.5314 - val_loss: 1.7561 - learning_rate: 2.5000e-04
# Epoch 67/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9018 - loss: 1.1019 - val_accuracy: 0.4140 - val_loss: 2.1630 - learning_rate: 2.5000e-04
# Epoch 68/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8939 - loss: 1.1388 - val_accuracy: 0.5342 - val_loss: 1.7665 - learning_rate: 2.5000e-04
# Epoch 69/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8992 - loss: 1.0586 - val_accuracy: 0.4982 - val_loss: 1.8750 - learning_rate: 2.5000e-04
# Epoch 70/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8735 - loss: 1.1905 - val_accuracy: 0.5018 - val_loss: 1.8729 - learning_rate: 2.5000e-04
# Epoch 71/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8631 - loss: 1.1806 - val_accuracy: 0.5333 - val_loss: 1.7088 - learning_rate: 2.5000e-04
# Epoch 72/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9060 - loss: 1.1153 - val_accuracy: 0.5166 - val_loss: 1.8342 - learning_rate: 2.5000e-04
# Epoch 73/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8782 - loss: 1.2274 - val_accuracy: 0.4104 - val_loss: 2.1737 - learning_rate: 2.5000e-04
# Epoch 74/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8868 - loss: 1.1438 - val_accuracy: 0.4861 - val_loss: 1.8433 - learning_rate: 2.5000e-04
# Epoch 75/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8580 - loss: 1.1487 - val_accuracy: 0.4584 - val_loss: 1.9904 - learning_rate: 2.5000e-04
# Epoch 76/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8860 - loss: 1.0340 - val_accuracy: 0.4732 - val_loss: 1.9350 - learning_rate: 2.5000e-04
# Epoch 77/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8588 - loss: 1.2863 - val_accuracy: 0.5166 - val_loss: 1.7815 - learning_rate: 2.5000e-04
# Epoch 78/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9222 - loss: 1.0251 - val_accuracy: 0.4852 - val_loss: 1.9216 - learning_rate: 2.5000e-04
# Epoch 79/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8169 - loss: 1.2923
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8175 - loss: 1.2902 - val_accuracy: 0.4834 - val_loss: 1.9300 - learning_rate: 2.5000e-04
# Epoch 80/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9250 - loss: 0.9915 - val_accuracy: 0.5065 - val_loss: 1.8394 - learning_rate: 1.2500e-04
# Epoch 81/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9119 - loss: 1.0600 - val_accuracy: 0.5481 - val_loss: 1.7063 - learning_rate: 1.2500e-04
# Epoch 82/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8886 - loss: 1.1320 - val_accuracy: 0.5675 - val_loss: 1.6513 - learning_rate: 1.2500e-04
# Epoch 83/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9099 - loss: 1.0143 - val_accuracy: 0.5148 - val_loss: 1.7824 - learning_rate: 1.2500e-04
# Epoch 84/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9102 - loss: 1.0565 - val_accuracy: 0.5407 - val_loss: 1.7611 - learning_rate: 1.2500e-04
# Epoch 85/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9224 - loss: 0.9757 - val_accuracy: 0.5342 - val_loss: 1.7155 - learning_rate: 1.2500e-04
# Epoch 86/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8807 - loss: 1.0714 - val_accuracy: 0.5462 - val_loss: 1.7040 - learning_rate: 1.2500e-04
# Epoch 87/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8896 - loss: 1.1046 - val_accuracy: 0.5416 - val_loss: 1.6893 - learning_rate: 1.2500e-04
# Epoch 88/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9589 - loss: 0.8891 - val_accuracy: 0.5545 - val_loss: 1.6576 - learning_rate: 1.2500e-04
# Epoch 89/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9573 - loss: 0.8812 - val_accuracy: 0.5231 - val_loss: 1.8293 - learning_rate: 1.2500e-04
# Epoch 90/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9272 - loss: 1.0105 - val_accuracy: 0.5591 - val_loss: 1.6584 - learning_rate: 1.2500e-04
# Epoch 91/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9168 - loss: 0.9914 - val_accuracy: 0.5129 - val_loss: 1.7456 - learning_rate: 1.2500e-04
# Epoch 92/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9209 - loss: 0.9889 - val_accuracy: 0.5120 - val_loss: 1.8485 - learning_rate: 1.2500e-04
# Epoch 93/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9167 - loss: 0.9986 - val_accuracy: 0.5573 - val_loss: 1.6572 - learning_rate: 1.2500e-04
# Epoch 94/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9389 - loss: 0.9385 - val_accuracy: 0.5518 - val_loss: 1.6410 - learning_rate: 1.2500e-04
# Epoch 95/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9675 - loss: 0.8726 - val_accuracy: 0.5240 - val_loss: 1.7837 - learning_rate: 1.2500e-04
# Epoch 96/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9376 - loss: 0.8661 - val_accuracy: 0.5416 - val_loss: 1.6868 - learning_rate: 1.2500e-04
# Epoch 97/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9616 - loss: 0.8077 - val_accuracy: 0.5222 - val_loss: 1.7868 - learning_rate: 1.2500e-04
# Epoch 98/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9203 - loss: 1.0076 - val_accuracy: 0.5259 - val_loss: 1.7166 - learning_rate: 1.2500e-04
# Epoch 99/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9424 - loss: 0.8970 - val_accuracy: 0.5231 - val_loss: 1.7543 - learning_rate: 1.2500e-04
# Epoch 100/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9191 - loss: 1.0026 - val_accuracy: 0.4954 - val_loss: 1.8328 - learning_rate: 1.2500e-04
# Epoch 101/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9279 - loss: 0.8881 - val_accuracy: 0.4760 - val_loss: 1.9079 - learning_rate: 1.2500e-04
# Epoch 102/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9387 - loss: 0.9192
# Epoch 102: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9385 - loss: 0.9198 - val_accuracy: 0.5120 - val_loss: 1.8165 - learning_rate: 1.2500e-04
# Epoch 103/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9475 - loss: 0.8893 - val_accuracy: 0.5527 - val_loss: 1.6314 - learning_rate: 6.2500e-05
# Epoch 104/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9056 - loss: 0.9653 - val_accuracy: 0.5712 - val_loss: 1.6106 - learning_rate: 6.2500e-05
# Epoch 105/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9406 - loss: 0.9365 - val_accuracy: 0.5693 - val_loss: 1.5944 - learning_rate: 6.2500e-05
# Epoch 106/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9494 - loss: 0.8960 - val_accuracy: 0.5407 - val_loss: 1.7002 - learning_rate: 6.2500e-05
# Epoch 107/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9363 - loss: 0.8536 - val_accuracy: 0.5665 - val_loss: 1.6089 - learning_rate: 6.2500e-05
# Epoch 108/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9166 - loss: 1.0035 - val_accuracy: 0.5471 - val_loss: 1.6766 - learning_rate: 6.2500e-05
# Epoch 109/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9308 - loss: 0.9033 - val_accuracy: 0.5277 - val_loss: 1.7427 - learning_rate: 6.2500e-05
# Epoch 110/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9258 - loss: 0.9253 - val_accuracy: 0.5388 - val_loss: 1.6810 - learning_rate: 6.2500e-05
# Epoch 111/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9354 - loss: 0.9855 - val_accuracy: 0.5628 - val_loss: 1.6033 - learning_rate: 6.2500e-05
# Epoch 112/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9444 - loss: 0.8803 - val_accuracy: 0.5610 - val_loss: 1.6181 - learning_rate: 6.2500e-05
# Epoch 113/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9192 - loss: 0.9516 - val_accuracy: 0.5749 - val_loss: 1.6206 - learning_rate: 6.2500e-05
# Epoch 114/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8927 - loss: 0.9276 - val_accuracy: 0.5536 - val_loss: 1.6104 - learning_rate: 6.2500e-05
# Epoch 115/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9465 - loss: 0.8505 - val_accuracy: 0.5555 - val_loss: 1.6470 - learning_rate: 6.2500e-05
# Epoch 116/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9134 - loss: 1.0738 - val_accuracy: 0.5619 - val_loss: 1.6181 - learning_rate: 6.2500e-05
# Epoch 117/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9402 - loss: 0.9417 - val_accuracy: 0.5397 - val_loss: 1.6758 - learning_rate: 6.2500e-05
# Epoch 118/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9339 - loss: 0.9721 - val_accuracy: 0.5536 - val_loss: 1.6580 - learning_rate: 6.2500e-05
# Epoch 119/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9041 - loss: 0.9217 - val_accuracy: 0.5379 - val_loss: 1.6513 - learning_rate: 6.2500e-05
# Epoch 120/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9237 - loss: 0.9460 - val_accuracy: 0.5610 - val_loss: 1.6199 - learning_rate: 6.2500e-05
# Epoch 121/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9619 - loss: 0.8218 - val_accuracy: 0.5471 - val_loss: 1.6409 - learning_rate: 6.2500e-05
# Epoch 122/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9334 - loss: 0.8874 - val_accuracy: 0.5628 - val_loss: 1.6175 - learning_rate: 6.2500e-05
# Epoch 123/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9339 - loss: 0.8074 - val_accuracy: 0.5323 - val_loss: 1.6770 - learning_rate: 6.2500e-05
# Epoch 124/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8846 - loss: 0.9838 - val_accuracy: 0.5231 - val_loss: 1.6980 - learning_rate: 6.2500e-05
# Epoch 125/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9460 - loss: 0.8165 - val_accuracy: 0.5610 - val_loss: 1.6562 - learning_rate: 6.2500e-05
# Epoch 126/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9511 - loss: 0.9233 - val_accuracy: 0.4945 - val_loss: 1.7569 - learning_rate: 6.2500e-05
# Epoch 127/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9301 - loss: 0.7691 - val_accuracy: 0.5555 - val_loss: 1.6663 - learning_rate: 6.2500e-05
# Epoch 128/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9247 - loss: 0.9026 - val_accuracy: 0.5360 - val_loss: 1.6600 - learning_rate: 6.2500e-05
# Epoch 129/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9193 - loss: 0.9051 - val_accuracy: 0.5268 - val_loss: 1.7065 - learning_rate: 6.2500e-05
# Epoch 130/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8997 - loss: 1.0313 - val_accuracy: 0.5499 - val_loss: 1.6401 - learning_rate: 6.2500e-05
# Epoch 131/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9464 - loss: 1.0370 - val_accuracy: 0.5407 - val_loss: 1.6504 - learning_rate: 6.2500e-05
# Epoch 132/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9515 - loss: 0.9572 - val_accuracy: 0.5693 - val_loss: 1.6040 - learning_rate: 6.2500e-05
# Epoch 133/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9432 - loss: 0.8900
# Epoch 133: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9433 - loss: 0.8889 - val_accuracy: 0.5453 - val_loss: 1.6231 - learning_rate: 6.2500e-05
# Epoch 134/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9654 - loss: 0.8293 - val_accuracy: 0.5619 - val_loss: 1.6064 - learning_rate: 3.1250e-05
# Epoch 135/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.9110 - loss: 0.9433 - val_accuracy: 0.5684 - val_loss: 1.6134 - learning_rate: 3.1250e-05
# Epoch 136/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9373 - loss: 0.8955 - val_accuracy: 0.5758 - val_loss: 1.5638 - learning_rate: 3.1250e-05
# Epoch 137/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9669 - loss: 0.8055 - val_accuracy: 0.5665 - val_loss: 1.5842 - learning_rate: 3.1250e-05
# Epoch 138/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.9289 - loss: 0.9239 - val_accuracy: 0.5536 - val_loss: 1.6243 - learning_rate: 3.1250e-05
# Epoch 139/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9195 - loss: 0.9347 - val_accuracy: 0.5656 - val_loss: 1.5953 - learning_rate: 3.1250e-05
# Epoch 140/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9625 - loss: 0.7769 - val_accuracy: 0.5721 - val_loss: 1.6029 - learning_rate: 3.1250e-05
# Epoch 141/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9577 - loss: 0.7491 - val_accuracy: 0.5527 - val_loss: 1.6203 - learning_rate: 3.1250e-05
# Epoch 142/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9515 - loss: 0.9565 - val_accuracy: 0.5712 - val_loss: 1.5803 - learning_rate: 3.1250e-05
# Epoch 143/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.9326 - loss: 0.7970 - val_accuracy: 0.5601 - val_loss: 1.6011 - learning_rate: 3.1250e-05
# Epoch 144/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9245 - loss: 0.8850 - val_accuracy: 0.5730 - val_loss: 1.5898 - learning_rate: 3.1250e-05
# Epoch 145/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9559 - loss: 0.7741 - val_accuracy: 0.5758 - val_loss: 1.6141 - learning_rate: 3.1250e-05
# Epoch 146/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9093 - loss: 0.9488 - val_accuracy: 0.5305 - val_loss: 1.6976 - learning_rate: 3.1250e-05
# Epoch 147/160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9315 - loss: 0.8083 - val_accuracy: 0.5767 - val_loss: 1.5707 - learning_rate: 3.1250e-05
# Epoch 148/160
# ...
# Epoch 37/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7229 - loss: 1.6101 - val_accuracy: 0.5005 - val_loss: 1.8994 - learning_rate: 5.0000e-04
# Epoch 38/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6745 - loss: 1.7091 - val_accuracy: 0.4168 - val_loss: 2.2846 - learning_rate: 5.0000e-04
# Epoch 39/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7265 - loss: 1.5908 - val_accuracy: 0.4369 - val_loss: 2.0575 - learning_rate: 5.0000e-04
# Epoch 40/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7367 - loss: 1.5354 - val_accuracy: 0.3673 - val_loss: 2.2638 - learning_rate: 5.0000e-04
# Epoch 41/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7332 - loss: 1.5772 - val_accuracy: 0.4672 - val_loss: 1.9929 - learning_rate: 5.0000e-04
# Epoch 42/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7309 - loss: 1.6214 - val_accuracy: 0.4390 - val_loss: 2.0816 - learning_rate: 5.0000e-04
# Epoch 43/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7363 - loss: 1.5248 - val_accuracy: 0.4490 - val_loss: 2.0166 - learning_rate: 5.0000e-04
# Epoch 44/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7712 - loss: 1.4688 - val_accuracy: 0.3744 - val_loss: 2.3866 - learning_rate: 5.0000e-04
# Epoch 45/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7510 - loss: 1.5058 - val_accuracy: 0.5045 - val_loss: 1.8050 - learning_rate: 5.0000e-04
# Epoch 46/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7627 - loss: 1.4676 - val_accuracy: 0.4430 - val_loss: 2.0330 - learning_rate: 5.0000e-04
# Epoch 47/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7898 - loss: 1.4783 - val_accuracy: 0.3774 - val_loss: 2.3017 - learning_rate: 5.0000e-04
# Epoch 48/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.7942 - loss: 1.4209 - val_accuracy: 0.4228 - val_loss: 2.2282 - learning_rate: 5.0000e-04
# Epoch 49/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.7833 - loss: 1.4083 - val_accuracy: 0.4541 - val_loss: 2.0333 - learning_rate: 5.0000e-04
# Epoch 50/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.7668 - loss: 1.5192 - val_accuracy: 0.4490 - val_loss: 2.0166 - learning_rate: 5.0000e-04
# Epoch 51/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8364 - loss: 1.2750 - val_accuracy: 0.3885 - val_loss: 2.4566 - learning_rate: 5.0000e-04
# Epoch 52/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.8122 - loss: 1.3182 - val_accuracy: 0.4410 - val_loss: 2.0228 - learning_rate: 5.0000e-04
# Epoch 53/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.7865 - loss: 1.4265 - val_accuracy: 0.3925 - val_loss: 2.3544 - learning_rate: 5.0000e-04
# Epoch 54/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7779 - loss: 1.4577 - val_accuracy: 0.5197 - val_loss: 1.7944 - learning_rate: 5.0000e-04
# Epoch 55/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8468 - loss: 1.1733 - val_accuracy: 0.4289 - val_loss: 2.2732 - learning_rate: 5.0000e-04
# Epoch 56/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8051 - loss: 1.3518 - val_accuracy: 0.3956 - val_loss: 2.1859 - learning_rate: 5.0000e-04
# Epoch 57/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.8035 - loss: 1.4240 - val_accuracy: 0.5035 - val_loss: 1.8288 - learning_rate: 5.0000e-04
# Epoch 58/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8425 - loss: 1.2611 - val_accuracy: 0.4904 - val_loss: 1.8989 - learning_rate: 5.0000e-04
# Epoch 59/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8264 - loss: 1.3167 - val_accuracy: 0.4551 - val_loss: 2.0256 - learning_rate: 5.0000e-04
# Epoch 60/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8791 - loss: 1.1835 - val_accuracy: 0.3946 - val_loss: 2.4790 - learning_rate: 5.0000e-04
# Epoch 61/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8286 - loss: 1.3078 - val_accuracy: 0.4309 - val_loss: 2.1185 - learning_rate: 5.0000e-04
# Epoch 62/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8451 - loss: 1.2305 - val_accuracy: 0.4309 - val_loss: 2.1906 - learning_rate: 5.0000e-04
# Epoch 63/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8158 - loss: 1.3145 - val_accuracy: 0.5217 - val_loss: 1.8051 - learning_rate: 5.0000e-04
# Epoch 64/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8680 - loss: 1.2119 - val_accuracy: 0.5197 - val_loss: 1.8162 - learning_rate: 5.0000e-04
# Epoch 65/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8308 - loss: 1.2989 - val_accuracy: 0.3209 - val_loss: 2.4497 - learning_rate: 5.0000e-04
# Epoch 66/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8757 - loss: 1.0952 - val_accuracy: 0.5187 - val_loss: 1.8969 - learning_rate: 5.0000e-04
# Epoch 67/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8769 - loss: 1.1785 - val_accuracy: 0.4480 - val_loss: 2.0360 - learning_rate: 5.0000e-04
# Epoch 68/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8242 - loss: 1.2848 - val_accuracy: 0.4147 - val_loss: 2.2966 - learning_rate: 5.0000e-04
# Epoch 69/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8600 - loss: 1.1556 - val_accuracy: 0.4854 - val_loss: 1.9047 - learning_rate: 5.0000e-04
# Epoch 70/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8137 - loss: 1.3566 - val_accuracy: 0.4147 - val_loss: 2.1279 - learning_rate: 5.0000e-04
# Epoch 71/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8378 - loss: 1.3715 - val_accuracy: 0.4612 - val_loss: 1.9602 - learning_rate: 5.0000e-04
# Epoch 72/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8904 - loss: 1.1110 - val_accuracy: 0.4279 - val_loss: 2.1679 - learning_rate: 5.0000e-04
# Epoch 73/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.8629 - loss: 1.1938 - val_accuracy: 0.3623 - val_loss: 2.2770 - learning_rate: 5.0000e-04
# Epoch 74/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.8697 - loss: 1.2242 - val_accuracy: 0.4511 - val_loss: 2.0455 - learning_rate: 5.0000e-04
# Epoch 75/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.8379 - loss: 1.3020 - val_accuracy: 0.4036 - val_loss: 2.2332 - learning_rate: 5.0000e-04
# Epoch 76/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8158 - loss: 1.3695 - val_accuracy: 0.2644 - val_loss: 2.7595 - learning_rate: 5.0000e-04
# Epoch 77/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8227 - loss: 1.3125 - val_accuracy: 0.4743 - val_loss: 1.9163 - learning_rate: 5.0000e-04
# Epoch 78/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8232 - loss: 1.2677 - val_accuracy: 0.4793 - val_loss: 1.9566 - learning_rate: 5.0000e-04
# Epoch 79/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8713 - loss: 1.1594 - val_accuracy: 0.4087 - val_loss: 2.1401 - learning_rate: 5.0000e-04
# Epoch 80/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8578 - loss: 1.1907 - val_accuracy: 0.3764 - val_loss: 2.3312 - learning_rate: 5.0000e-04
# Epoch 81/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8707 - loss: 1.1790 - val_accuracy: 0.4692 - val_loss: 1.9633 - learning_rate: 5.0000e-04
# Epoch 82/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8884 - loss: 1.1658 - val_accuracy: 0.4188 - val_loss: 2.2722 - learning_rate: 5.0000e-04
# Epoch 83/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8564 - loss: 1.2866
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8563 - loss: 1.2858 - val_accuracy: 0.3845 - val_loss: 2.2791 - learning_rate: 5.0000e-04
# Epoch 84/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8924 - loss: 1.1536 - val_accuracy: 0.4460 - val_loss: 2.0085 - learning_rate: 2.5000e-04
# Epoch 85/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9016 - loss: 1.0573 - val_accuracy: 0.5015 - val_loss: 1.9922 - learning_rate: 2.5000e-04
# Epoch 86/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9461 - loss: 1.0298 - val_accuracy: 0.4965 - val_loss: 1.9283 - learning_rate: 2.5000e-04
# Epoch 87/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9217 - loss: 1.0412 - val_accuracy: 0.5308 - val_loss: 1.7768 - learning_rate: 2.5000e-04
# Epoch 88/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9150 - loss: 1.1684 - val_accuracy: 0.4844 - val_loss: 1.8876 - learning_rate: 2.5000e-04
# Epoch 89/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9338 - loss: 1.0439 - val_accuracy: 0.4753 - val_loss: 1.9028 - learning_rate: 2.5000e-04
# Epoch 90/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9191 - loss: 1.0441 - val_accuracy: 0.4884 - val_loss: 1.9018 - learning_rate: 2.5000e-04
# Epoch 91/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9098 - loss: 1.1514 - val_accuracy: 0.4793 - val_loss: 1.9066 - learning_rate: 2.5000e-04
# Epoch 92/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9220 - loss: 1.0633 - val_accuracy: 0.4299 - val_loss: 2.0755 - learning_rate: 2.5000e-04
# Epoch 93/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9384 - loss: 0.9569 - val_accuracy: 0.4642 - val_loss: 1.8879 - learning_rate: 2.5000e-04
# Epoch 94/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9360 - loss: 1.0177 - val_accuracy: 0.4682 - val_loss: 1.8807 - learning_rate: 2.5000e-04
# Epoch 95/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8918 - loss: 1.0258 - val_accuracy: 0.4601 - val_loss: 1.9175 - learning_rate: 2.5000e-04
# Epoch 96/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9170 - loss: 1.0469 - val_accuracy: 0.4753 - val_loss: 2.0109 - learning_rate: 2.5000e-04
# Epoch 97/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9197 - loss: 0.9506 - val_accuracy: 0.4622 - val_loss: 1.8900 - learning_rate: 2.5000e-04
# Epoch 98/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9328 - loss: 0.9395 - val_accuracy: 0.4763 - val_loss: 2.0060 - learning_rate: 2.5000e-04
# Epoch 99/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8930 - loss: 1.1035 - val_accuracy: 0.4248 - val_loss: 2.1447 - learning_rate: 2.5000e-04
# Epoch 100/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9196 - loss: 0.9929 - val_accuracy: 0.4218 - val_loss: 2.0502 - learning_rate: 2.5000e-04
# Epoch 101/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8779 - loss: 1.1608 - val_accuracy: 0.4390 - val_loss: 2.0123 - learning_rate: 2.5000e-04
# Epoch 102/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9131 - loss: 1.0231 - val_accuracy: 0.4067 - val_loss: 2.1649 - learning_rate: 2.5000e-04
# Epoch 103/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9195 - loss: 1.0004 - val_accuracy: 0.4339 - val_loss: 2.0283 - learning_rate: 2.5000e-04
# Epoch 104/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8992 - loss: 1.0683 - val_accuracy: 0.5005 - val_loss: 1.8301 - learning_rate: 2.5000e-04
# Epoch 105/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9060 - loss: 1.0753 - val_accuracy: 0.5015 - val_loss: 1.8245 - learning_rate: 2.5000e-04
# Epoch 106/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9522 - loss: 0.8980 - val_accuracy: 0.4612 - val_loss: 1.9546 - learning_rate: 2.5000e-04
# Epoch 107/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9183 - loss: 0.9762
# Epoch 107: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9181 - loss: 0.9772 - val_accuracy: 0.4743 - val_loss: 1.9263 - learning_rate: 2.5000e-04
# Epoch 108/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8673 - loss: 1.1712 - val_accuracy: 0.4955 - val_loss: 1.8174 - learning_rate: 1.2500e-04
# Epoch 109/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9331 - loss: 0.9816 - val_accuracy: 0.5015 - val_loss: 1.8326 - learning_rate: 1.2500e-04
# Epoch 110/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9338 - loss: 0.9602 - val_accuracy: 0.4945 - val_loss: 1.8049 - learning_rate: 1.2500e-04
# Epoch 111/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8926 - loss: 1.0862 - val_accuracy: 0.5116 - val_loss: 1.7748 - learning_rate: 1.2500e-04
# Epoch 112/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9386 - loss: 0.9024 - val_accuracy: 0.4844 - val_loss: 1.8407 - learning_rate: 1.2500e-04
# Epoch 113/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9145 - loss: 0.9601 - val_accuracy: 0.5187 - val_loss: 1.7787 - learning_rate: 1.2500e-04
# Epoch 114/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9525 - loss: 0.7911 - val_accuracy: 0.4642 - val_loss: 1.9283 - learning_rate: 1.2500e-04
# Epoch 115/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9478 - loss: 0.8308 - val_accuracy: 0.5227 - val_loss: 1.7528 - learning_rate: 1.2500e-04
# Epoch 116/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.9762 - loss: 0.7275 - val_accuracy: 0.4965 - val_loss: 1.8792 - learning_rate: 1.2500e-04
# Epoch 117/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9583 - loss: 0.8755 - val_accuracy: 0.5308 - val_loss: 1.7416 - learning_rate: 1.2500e-04
# Epoch 118/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8989 - loss: 0.9977 - val_accuracy: 0.4753 - val_loss: 1.8327 - learning_rate: 1.2500e-04
# Epoch 119/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9488 - loss: 0.8071 - val_accuracy: 0.4995 - val_loss: 1.8194 - learning_rate: 1.2500e-04
# Epoch 120/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9465 - loss: 0.9073 - val_accuracy: 0.4874 - val_loss: 1.8503 - learning_rate: 1.2500e-04
# Epoch 121/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9448 - loss: 0.9049 - val_accuracy: 0.4934 - val_loss: 1.8270 - learning_rate: 1.2500e-04
# Epoch 122/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9234 - loss: 1.0086 - val_accuracy: 0.4854 - val_loss: 1.7937 - learning_rate: 1.2500e-04
# Epoch 123/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9598 - loss: 0.7904 - val_accuracy: 0.4823 - val_loss: 1.8891 - learning_rate: 1.2500e-04
# Epoch 124/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9252 - loss: 0.8710 - val_accuracy: 0.4632 - val_loss: 1.9357 - learning_rate: 1.2500e-04
# Epoch 125/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9149 - loss: 0.9760 - val_accuracy: 0.5106 - val_loss: 1.7848 - learning_rate: 1.2500e-04
# Epoch 126/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9564 - loss: 0.8094 - val_accuracy: 0.4400 - val_loss: 1.9832 - learning_rate: 1.2500e-04
# Epoch 127/160
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9524 - loss: 0.9261
# Epoch 127: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9525 - loss: 0.9252 - val_accuracy: 0.5076 - val_loss: 1.7978 - learning_rate: 1.2500e-04
# Epoch 127: early stopping
# Restoring model weights from the end of the best epoch: 87.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# Fold 5 - Accuracy: 0.5308, F1-macro: 0.5227
#
# === BFRB 8 Gestures Specialized CV Results ===
# CV Accuracy: 0.5431 ± 0.0194
# CV F1-macro: 0.5398 ± 0.0217
#
# === BFRB 8 Gestures Specialized Classification Report ===
#                           precision    recall  f1-score   support
#
#    Above ear - pull hair     0.5746    0.6034    0.5887       638
#       Cheek - pinch skin     0.4850    0.4584    0.4713       637
#      Eyebrow - pull hair     0.4117    0.3323    0.3677       638
#      Eyelash - pull hair     0.4904    0.5172    0.5034       640
# Forehead - pull hairline     0.6147    0.6281    0.6213       640
#       Forehead - scratch     0.6799    0.7469    0.7118       640
#        Neck - pinch skin     0.4793    0.5234    0.5004       640
#           Neck - scratch     0.5798    0.5391    0.5587       640
#
#                 accuracy                         0.5437      5113
#                macro avg     0.5394    0.5436    0.5404      5113
#             weighted avg     0.5395    0.5437    0.5405      5113

# %% [markdown]
# # Comparison

# %%
# Set style for better visualization
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
def plot_confusion_matrix(y_true, y_pred, class_names, title, figsize=(12, 10), 
                         normalize=True, cmap='Blues', save_path=None):
    """
    Create a beautiful confusion matrix visualization
    
    Parameters:
    - y_true: true labels
    - y_pred: predicted labels  
    - class_names: list of class names
    - title: plot title
    - figsize: figure size
    - normalize: whether to normalize the matrix
    - cmap: color map
    - save_path: path to save the plot
    """
    # Calculate confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.nan_to_num(cm)  # Handle division by zero
    
    # Create figure
    fig, ax = plt.subplots(figsize=figsize)
    
    # Create heatmap
    sns.heatmap(cm, annot=True, fmt='.3f' if normalize else 'd', 
                cmap=cmap, square=True, linewidths=0.5, 
                cbar_kws={'shrink': 0.8}, ax=ax)
    
    # Customize labels
    ax.set_xlabel('Predicted Label', fontsize=14, fontweight='bold')
    ax.set_ylabel('True Label', fontsize=14, fontweight='bold')
    ax.set_title(title, fontsize=16, fontweight='bold', pad=20)
    
    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    
    # Add text annotations for overall metrics
    accuracy = np.mean(y_true == y_pred)
    f1_macro = f1_score(y_true, y_pred, average='macro')
    
    # Add text box with metrics
    textstr = f'Accuracy: {accuracy:.3f}\nF1-Macro: {f1_macro:.3f}'
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.8)
    ax.text(0.02, 0.98, textstr, transform=ax.transAxes, fontsize=12,
            verticalalignment='top', bbox=props)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    plt.show()
    return fig

# %%
def plot_class_performance_comparison(results_all, results_bfrb, all_gesture_classes, 
                                   bfrb_gesture_classes, config):
    """
    Compare class-wise performance between all-gestures and BFRB-specialized models
    """
    # Extract BFRB classes from all-gestures results
    bfrb_indices_in_all = [i for i, gesture in enumerate(all_gesture_classes) 
                          if gesture in config.bfrb_gestures]
    
    all_true_labels = np.array(results_all['true_labels'])
    all_predictions = np.array(results_all['predictions'])
    
    # Filter BFRB predictions from all-gestures model
    bfrb_mask_in_results = np.isin(all_true_labels, bfrb_indices_in_all)
    bfrb_true_from_all = all_true_labels[bfrb_mask_in_results]
    bfrb_pred_from_all = all_predictions[bfrb_mask_in_results]
    
    # Map to BFRB-only scale
    bfrb_true_mapped = np.array([bfrb_indices_in_all.index(t) for t in bfrb_true_from_all])
    bfrb_pred_mapped = np.array([bfrb_indices_in_all.index(p) if p in bfrb_indices_in_all else -1 
                                for p in bfrb_pred_from_all])
    
    # Remove invalid predictions
    valid_mask = bfrb_pred_mapped != -1
    bfrb_true_final = bfrb_true_mapped[valid_mask]
    bfrb_pred_final = bfrb_pred_mapped[valid_mask]
    
    # Get BFRB specialized results
    bfrb_true_specialized = np.array(results_bfrb['true_labels'])
    bfrb_pred_specialized = np.array(results_bfrb['predictions'])
     
    # 1. All-gestures model confusion matrix (BFRB subset)
    plot_confusion_matrix(bfrb_true_final, bfrb_pred_final, 
                         bfrb_gesture_classes, 
                         "All-Gestures Model (BFRB Classes Only)",
                         figsize=(10, 8), normalize=True)
    
    # 2. BFRB specialized model confusion matrix
    plot_confusion_matrix(bfrb_true_specialized, bfrb_pred_specialized,
                         bfrb_gesture_classes,
                         "BFRB Specialized Model",
                         figsize=(10, 8), normalize=True)

# %%
plot_class_performance_comparison(results_all, results_bfrb, all_gesture_classes, bfrb_gesture_classes, config)

# %%
# Extract BFRB performance from all-gestures model
bfrb_indices_in_all = [i for i, gesture in enumerate(all_gesture_classes) 
                      if gesture in config.bfrb_gestures]

# Filter predictions for BFRB classes from all-gestures model
all_true_labels = np.array(results_all['true_labels'])
all_predictions = np.array(results_all['predictions'])

bfrb_mask_in_results = np.isin(all_true_labels, bfrb_indices_in_all)
bfrb_true_from_all = all_true_labels[bfrb_mask_in_results]
bfrb_pred_from_all = all_predictions[bfrb_mask_in_results]

# Map indices to BFRB-only scale
bfrb_true_mapped = np.array([bfrb_indices_in_all.index(t) for t in bfrb_true_from_all])
bfrb_pred_mapped = np.array([bfrb_indices_in_all.index(p) if p in bfrb_indices_in_all else -1 
                            for p in bfrb_pred_from_all])

# Remove invalid predictions
valid_mask = bfrb_pred_mapped != -1
bfrb_true_final = bfrb_true_mapped[valid_mask]
bfrb_pred_final = bfrb_pred_mapped[valid_mask]

# Calculate BFRB performance from all-gestures model
bfrb_acc_from_all = np.mean(bfrb_true_final == bfrb_pred_final)
bfrb_f1_from_all = f1_score(bfrb_true_final, bfrb_pred_final, average='macro')

# Comparison table
print(f"\n{'Metric':<25} {'All Gestures':<15} {'BFRB from All':<15} {'BFRB Specialized':<18} {'Improvement':<12}")
print("-" * 85)
print(f"{'Overall Accuracy':<25} {results_all['overall_accuracy']:<15.4f} {bfrb_acc_from_all:<15.4f} {results_bfrb['overall_accuracy']:<18.4f} {results_bfrb['overall_accuracy']/bfrb_acc_from_all:<12.2f}x")
print(f"{'Overall F1-Macro':<25} {results_all['overall_f1_macro']:<15.4f} {bfrb_f1_from_all:<15.4f} {results_bfrb['overall_f1_macro']:<18.4f} {results_bfrb['overall_f1_macro']/bfrb_f1_from_all:<12.2f}x")

print(f"\n=== Key Findings ===")
print(f"• BFRB specialized model achieves {results_bfrb['overall_accuracy']:.4f} accuracy vs {bfrb_acc_from_all:.4f} from all-gestures model")
print(f"• Improvement in BFRB classification: {(results_bfrb['overall_accuracy']/bfrb_acc_from_all - 1)*100:.1f}%")
print(f"• F1-macro improvement: {(results_bfrb['overall_f1_macro']/bfrb_f1_from_all - 1)*100:.1f}%")

if results_bfrb['overall_accuracy'] > bfrb_acc_from_all:
    print(f"✅ HYPOTHESIS CONFIRMED: Specialized BFRB model outperforms general model for BFRB classification")
else:
    print(f"❌ HYPOTHESIS REJECTED: General model performs better or similar for BFRB classification")
# Out:
# Metric                    All Gestures    BFRB from All   BFRB Specialized   Improvement
# -------------------------------------------------------------------------------------
# Overall Accuracy          0.6677          0.5730          0.5431             0.95        x
# Overall F1-Macro          0.7043          0.5710          0.5398             0.95        x
#
# === Key Findings ===
# • BFRB specialized model achieves 0.5431 accuracy vs 0.5730 from all-gestures model
# • Improvement in BFRB classification: -5.2%
# • F1-macro improvement: -5.5%
# ❌ HYPOTHESIS REJECTED: General model performs better or similar for BFRB classification
